# %%
# %matplotlib inline
from __future__ import print_function, division
import tellurium as te
import roadrunner
from roadrunner import SelectionRecord
from matplotlib import pyplot as plt

# %%
# load model
r = te.loads('AssignmentTest_1.xml')
print(r.getCurrentAntimony())

# %%
-
# Out:
# 0.0
# 0.0
# 0.0
# 0.0
