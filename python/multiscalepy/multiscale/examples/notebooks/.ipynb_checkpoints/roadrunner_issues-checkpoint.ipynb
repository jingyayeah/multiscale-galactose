# %% [markdown]
# # Parameter slider

# %%
# %matplotlib inline
import tellurium as te
from tellurium.widgets import ParameterSlider

model = '''
      model pathway()
        S1 -> S2; k1*S1 - k2*S2 # Reversible term added here

        # Initialize values
        S1 = 5; S2 = 0;
        k1 = 0.1;  k2 = 0.05;

      end
'''
r = te.loadAntimonyModel(model)
ParameterSlider(r, paramIds=['k1']);

# %%
model = '''
      model pathway()
        S1 -> S2; k1*S1 - k2*S2 # Reversible term added here

        # Initialize values
        S1 = 5; S2 = 0;
        k1 = 0.1;  k2 = 0.05;

      end
'''
r = te.loada(model)
# works
r.selections = ["time", "[S1]"]
s = r.simulate(10, 20)
r.plot()
# works
s = r.simulate(10, 20, ["time", "[S1]"])
r.plot()
#fails
s = r.simulate(10, 20, selections=["time", "[S1]"])
r.plot()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-d5285c998504> in <module>()
#      18 r.plot()
#      19 #fails
# ---> 20 s = r.simulate(10, 20, selections= ["time", "[S1]"])
#      21 r.plot()
#      22
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in simulate(self, *args, **kwargs)
#    2947             # if the inegrator cares about it, it will use it.
#    2948             # if its one of these, set it.
# -> 2949             o[k] = v
#    2950
#    2951
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in __setitem__(self, *args)
#     308     def items(self): return _roadrunner.Dictionary_items(self)
#     309     def __getitem__(self, *args): return _roadrunner.Dictionary___getitem__(self, *args)
# --> 310     def __setitem__(self, *args): return _roadrunner.Dictionary___setitem__(self, *args)
#     311     def __delitem__(self, *args): return _roadrunner.Dictionary___delitem__(self, *args)
#     312     def __contains__(self, *args): return _roadrunner.Dictionary___contains__(self, *args)
#
# RuntimeError: could not convert Python type to built in type

# %%
from __future__ import print_function, division

import roadrunner
from roadrunner import SelectionRecord
print(roadrunner.__version__)

# Model definition via antimony.
# The model contains an Event triggered at t=2 [s].
r = te.loada("""
    model event_time()
    // Reactions
    J0: $PP_S -> 2 S3; K1 * PP_S;

    // Species initializations:
    var species S3;
    var species S4;
    S3 = 0.5;
    PP_S = 0.0;
    S4 := 2*S3;

    // Rule for S1
    K1 = 0.5;    
    
    // Additional events for triggering re-integration
    E1: at(time>=2):  S3=5;  
    end
""")

r.selections = ['time'] + r.model.getBoundarySpeciesIds() + r.model.getFloatingSpeciesIds() + r.model.getReactionIds()
print(r.selections)

absTol = 1E-6 * min(r.model.getCompartmentVolumes())
relTol = 1E-6


# 
s = r.simulate(0, 7, absolute=absTol, relative=relTol, variableStep=False, stiff=False, plot=True)
print(r)
# Out:
# 1.4.2; Compiler: gcc 4.8.4, C++ version: 199711; JIT Compiler: LLVM-3.4; Date: Feb  1 2016, 15:48:52; LibSBML Version: 5.12.0
# ['time', 'PP_S', 'S3', 'S4', 'J0']
# <roadrunner.RoadRunner() {
# 'this' : 0x3a33de0
# 'modelLoaded' : true
# 'modelName' : event_time
# 'libSBMLVersion' : LibSBML Version: 5.12.0
# 'jacobianStepSize' : 1e-05
# 'conservedMoietyAnalysis' : false
# 'simulateOptions' :
# < roadrunner.SimulateOptions()
# {
# 'this' : 0x128fc30,
# 'reset' : 0,
# 'structuredResult' : 0,
# 'copyResult' : 1,
# 'steps' : 50,
# 'start' : 0,
# 'duration' : 7,
# 'stiff' : false,
# 'absolute' : 0.000001,
# 'relative' : 0.000001
# }>,
# 'integrator' :
# < roadrunner.Integrator() >
#   settings:
#       relative_tolerance: 0.00001
#       absolute_tolerance: 0.0000000001
#                    stiff: false
#        maximum_bdf_order: 5
#      maximum_adams_order: 12
#        maximum_num_steps: 20000
#        maximum_time_step: 0
#        minimum_time_step: 0
#        initial_time_step: 0
#           multiple_steps: false
#       variable_step_size: false
#
# }>
