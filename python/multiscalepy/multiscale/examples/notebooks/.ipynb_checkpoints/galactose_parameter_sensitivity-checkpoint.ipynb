# %% [markdown]
# # Parameter sensitivity
#
# Analysis of the effect of parameter changes on the output of standard simulations. The single cell clearance model of galactose metabolism is tested.

# %%
from __future__ import print_function, division
# %matplotlib inline

# %%
# simulation & model database
import django
django.setup()
# import the database API functions and tools
import simapp.db.api as db_api
import multiscale.odesim.db.tools as db_tools

# %%
# create model in database
import multiscale.examples.testdata as testdata
reload(testdata)

comp_model = db_api.create_model(filepath=testdata.galactose_singlecell_sbml)
if not comp_model:
    # TODO: fix how to get models !
    from simapp.models import CompModel
    comp_models = CompModel.objects.filter(model_id='galactose_29_annotated')
    comp_model = comp_models[0]
print(comp_model)
# Out:
# <SBML: galactose_30_annotated>

# %% [markdown]
# ## Reference simulation
# Reference simulation against which the parameter changes are tested.

# %%
import roadrunner
from roadrunner import SelectionRecord
print(roadrunner.getVersionStr())
# Out:
# 1.4.2; Compiler: gcc 4.8.4, C++ version: 199711; JIT Compiler: LLVM-3.4; Date: Jan 20 2016, 08:49:40

# %%
# standard simulation 
import multiscale.odesim.simulate.roadrunner_tools as rt
reload(rt)




# load model
r = rt.load_model(comp_model.filepath)
# selections
r.selections = ['time'] + ['[{}]'.format(s) for s in r.model.getFloatingSpeciesIds()]
print(r.selections)
# settings
rt.set_integrator_settings(r)
# simulate
s, _ = rt.simulate(r, 0, 1000)
r.plot()
rt.plot_results([s])

# store final concentrations
c1 = rt.store_concentrations(r)
# Out:
# Loading : /home/mkoenig/multiscale-galactose-results/django/model/galactose_30_annotated.xml
# SBML load time: 0.541792869568
# ['time', '[c__ppi]', '[e__h2oM]', '[c__glc1p]', '[c__udpgal]', '[c__udp]', '[c__atp]', '[c__utp]', '[e__gal]', '[c__gal1pM]', '[c__gal]', '[c__galtolM]', '[e__galM]', '[c__glc6p]', '[c__adp]', '[h__h2oM]', '[c__nadp]', '[c__udpgalM]', '[c__galM]', '[c__galtol]', '[c__nadph]', '[c__glc6pM]', '[c__glc1pM]', '[c__udpglc]', '[c__gal1p]', '[c__udpglcM]', '[c__phos]']
# Integration time: 0.00772285461426

# %%
# Galactose challenge after certain amount of time.
# What are the effects of parameter changes in the model (analysis of variability)
# Test galactose challenge

import numpy as np
from roadrunner import SelectionRecord
reload(rt)

# Changed fixed boundary conditions
r.reset(SelectionRecord.ALL)  # reset model

# storage for partial results
results = []
tends = [20, 100, 200]
Nsim = 10

for k in xrange(Nsim):
    # simulate & store concentrations at end point
    s1 = r.simulate(0, tends[0])
    c1 = rt.store_concentrations(r)

    # change boundary concentrations
    e__gal = r.e__gal  # store old value
    r.e__gal = k+1       # set new value
    s2 = r.simulate(tends[0], tends[1])
    
    # reset values
    r.e__gal = e__gal  # restore value
    s3 = r.simulate(tends[1], tends[2])
    
    s = np.concatenate([s1, s2, s3], axis=0)
    results.append(s)

# plot the results
rt.plot_results(results, '-', alpha=0.7)

# plot histograms: TODO: how different are the start from the end points

# %% [markdown]
# ## Test zero concentrations
# Check if all external concentrations can be set to zero in the model.

# %%
import libsbml
import matplotlib.pylab as plt
doc = libsbml.readSBML(comp_model.filepath)
model = doc.getModel()

# get all external species ids
e_species = []
for s in model.species:
    if (s.compartment == 'e'):
        e_species.append(s)

# set them to zero and simulate
reload(rt)
r = rt.load_model(comp_model.filepath)
rt.set_integrator_settings(r)

for e_id in e_species:
    print(e_id)
    s, __ = rt.simulate(r, 0, 1000, init_concentrations={e_id.id: 0.0})
    rt.plot_results([s])
    
r.getIntegrator().getSetting('variable_step_size')
print(type(r))
isinstance(r, roadrunner.roadrunner.RoadRunner)
# Out:
# Loading : /home/mkoenig/multiscale-galactose-results/django/model/galactose_30_annotated.xml
# SBML load time: 0.159245967865
# <Species e__h2oM "water M*">
# Integration time: 0.00758695602417
# <Species e__gal "D-galactose">
# Integration time: 0.00739789009094
# <Species e__galM "D-galactose M*">
# Integration time: 0.00739002227783
# <class 'roadrunner.roadrunner.RoadRunner'>
# True

# %% [markdown]
# ## Test parameter change
# Change all parameters in the model via 10% and see the effect on the model simulations

# %%
# implement the parameter changes
reload(rt)

# TODO: refactor in standard method (standard application of s)
# single parameter variation, double parameter variation, initial concentration variation, initial amount variation.


# All global parameters which are constant have to be varied.
parameter_ids = r.model.getGlobalParameterIds()
import libsbml
doc = libsbml.readSBMLFromFile(comp_model.filepath)
model = doc.getModel()
const_parameter_ids = []
for pid in parameter_ids:
    par = model.getParameter(pid)
    if par.getConstant() == True:
        const_parameter_ids.append(pid)

# number of constant parameters (not calculated via assignment)
print('Number of parameters:', len(const_parameter_ids))

# and this is the amount
factors = [0.9, 1.1]

# repeated simulation
results = []
tends = [20, 50, 70]
gal_ext = [0, 2, 4, 8]

for k_pid, pid in enumerate(sorted(const_parameter_ids)):
    print(k_pid, ':', pid)
    for f in factors:
        for gal in gal_ext:
            # full reset
            r.reset(SelectionRecord.ALL)
            
            # change parameter
            c_backup = rt.store_concentrations(r)
            p_old = r[pid]
            r[pid] = f * p_old
            r.reset(SelectionRecord.INITIAL_GLOBAL_PARAMETER)
            rt.restore_concentrations(r, c_backup)  # restore concentrations
            
            # simulate
           
            s1 = r.simulate(0, tends[0])
            c1 = rt.store_concentrations(r)

            # change boundary concentrations
            e__gal = r.e__gal    # store old value
            r.e__gal = gal       # set new value
            s2 = r.simulate(tends[0], tends[1])

            # reset values
            r.e__gal = e__gal  # restore value
            s3 = r.simulate(tends[1], tends[2])

            s = np.concatenate([s1, s2, s3], axis=0)
            results.append(s)

# plot the results
rt.plot_results(results, '-', color='black', alpha=0.7)
# Out:
# Number of parameters: 100
# 0 : ALDR_f
# 1 : ALDR_k_gal
# 2 : ALDR_k_galtol
# 3 : ALDR_k_nadp
# 4 : ALDR_k_nadph
# 5 : ALDR_keq
# 6 : ATPS_f
# 7 : ATPS_k_adp
# 8 : ATPS_k_atp
# 9 : ATPS_k_phos
# 10 : ATPS_keq
# 11 : A_m
# 12 : GALE_PA
# 13 : GALE_f
# 14 : GALE_k_udpgal
# 15 : GALE_k_udpglc
# 16 : GALE_kcat
# 17 : GALE_keq
# 18 : GALK_PA
# 19 : GALK_k_adp
# 20 : GALK_k_atp
# 21 : GALK_k_gal
# 22 : GALK_k_gal1p
# 23 : GALK_kcat
# 24 : GALK_keq
# 25 : GALK_ki_gal1p
# 26 : GALT_f
# 27 : GALT_k_gal1p
# 28 : GALT_k_glc1p
# 29 : GALT_k_udpgal
# 30 : GALT_k_udpglc
# 31 : GALT_keq
# 32 : GALT_ki_udp
# 33 : GALT_ki_utp
# 34 : GALT_vm
# 35 : GLUT2_f
# 36 : GLUT2_k_gal
# 37 : GLY_f
# 38 : GLY_k_glc6p
# 39 : GLY_k_p
# 40 : GTF_f
# 41 : GTF_k_udpgal
# 42 : GTF_k_udpglc
# 43 : H2OT_f
# 44 : H2OT_k
# 45 : IMP_f
# 46 : IMP_k_gal1p
# 47 : NADPR_f
# 48 : NADPR_k_nadp
# 49 : NADPR_keq
# 50 : NADPR_ki_nadph
# 51 : NDKU_f
# 52 : NDKU_k_adp
# 53 : NDKU_k_atp
# 54 : NDKU_k_udp
# 55 : NDKU_k_utp
# 56 : NDKU_keq
# 57 : Nf
# 58 : PGM1_f
# 59 : PGM1_k_glc1p
# 60 : PGM1_k_glc6p
# 61 : PGM1_keq
# 62 : PPASE_f
# 63 : PPASE_k_ppi
# 64 : PPASE_n
# 65 : REF_P
# 66 : UGALP_f
# 67 : UGP_f
# 68 : UGP_k_gal1p
# 69 : UGP_k_glc1p
# 70 : UGP_k_ppi
# 71 : UGP_k_udpgal
# 72 : UGP_k_udpglc
# 73 : UGP_k_utp
# 74 : UGP_keq
# 75 : UGP_ki_udpglc
# 76 : UGP_ki_utp
# 77 : Vol_c
# 78 : Vol_e
# 79 : Vol_h
# 80 : c__ALDR_P
# 81 : c__ATPS_P
# 82 : c__GALE_P
# 83 : c__GALK_P
# 84 : c__GALT_P
# 85 : c__GLUT2_P
# 86 : c__GLY_P
# 87 : c__GTF_P
# 88 : c__IMP_P
# 89 : c__NADPR_P
# 90 : c__NDKU_P
# 91 : c__PGM1_P
# 92 : c__PPASE_P
# 93 : c__UGP_P
# 94 : deficiency
# 95 : f_cyto
# 96 : f_tissue
# 97 : scale_f
# 98 : x_cell
# 99 : y_cell

# %%
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <sbml xmlns="http://www.sbml.org/sbml/level3/version1/core" xmlns:fbc="http://www.sbml.org/sbml/level3/version1/fbc/version2" metaid="meta_c3730b3809e743dca5fe8197e5a61401" sboTerm="SBO:0000293" level="3" version="1" fbc:required="false">
#   <annotation>
#     <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#       <rdf:Description rdf:about="#meta_c3730b3809e743dca5fe8197e5a61401">
#         <bqmodel:is>
#           <rdf:Bag>
#             <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000293"/>
#           </rdf:Bag>
#         </bqmodel:is>
#       </rdf:Description>
#     </rdf:RDF>
#   </annotation>
#   <model metaid="meta_bb6a09df418d4b529a53c65aacb61855" id="galactose_30_annotated" name="galactose_30" substanceUnits="mole" timeUnits="s" volumeUnits="m3" areaUnits="m2" lengthUnits="m" extentUnits="mole" fbc:strict="false">
#     <notes>
#       <body xmlns="http://www.w3.org/1999/xhtml">
#         <h1>Koenig Human Galactose Metabolism</h1>
#         <h2>Description</h2>
#         <p>This is a metabolism model of Human galactose metabolism in
#     <a href="http://sbmlutils.org" target="_blank" title="Access the definition of the SBML file format.">SBML</a> format.
#     </p>
#       <div class="dc:provenance">The content of this model has been carefully created in a manual research effort.</div>
#       <div class="dc:publisher">This file has been produced by
#     <a href="https://livermetabolism.com/contact.html" title="Matthias Koenig" target="_blank">Matthias Koenig</a>.</div>
#     <h2>Terms of use</h2>
#     <div class="dc:rightsHolder">Copyright © 2015 Matthias Koenig.</div>
#     <div class="dc:license">
#       <p>Redistribution and use of any part of this model, with or without modification, are permitted provided that the following conditions are met:
#         <ol>
#         <li>Redistributions of this SBML file must retain the above copyright notice, this list of conditions and the following disclaimer.</li>
#         <li>Redistributions in a different form must reproduce the above copyright notice, this list of conditions and the following disclaimer in the documentation and/or other materials provided
#           with the distribution.</li>
#       </ol>
#         This model is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#         </p>
#   </div>
# </body>
# </notes><annotation>
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#     <rdf:Description rdf:about="#meta_bb6a09df418d4b529a53c65aacb61855">
#       <dc:creator>
#         <rdf:Bag>
#           <rdf:li rdf:parseType="Resource">
#             <vCard:N rdf:parseType="Resource">
#               <vCard:Family>Koenig</vCard:Family>
#               <vCard:Given>Matthias</vCard:Given>
#             </vCard:N>
#             <vCard:EMAIL>konigmatt@googlemail.com</vCard:EMAIL>
#             <vCard:ORG rdf:parseType="Resource">
#               <vCard:Orgname>Charite Berlin</vCard:Orgname>
#             </vCard:ORG>
#           </rdf:li>
#         </rdf:Bag>
#       </dc:creator>
#       <dcterms:created rdf:parseType="Resource">
#         <dcterms:W3CDTF>2016-01-19T15:42:24Z</dcterms:W3CDTF>
#       </dcterms:created>
#       <dcterms:modified rdf:parseType="Resource">
#         <dcterms:W3CDTF>2016-01-19T15:42:24Z</dcterms:W3CDTF>
#       </dcterms:modified>
#       <bqbiol:hasTaxon>
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/taxonomy/9606"/>
#         </rdf:Bag>
#       </bqbiol:hasTaxon>
#       <bqbiol:is>
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bto/BTO:0000759"/>
#           <rdf:li rdf:resource="http://identifiers.org/uberon/UBERON:2107"/>
#           <rdf:li rdf:resource="http://identifiers.org/fma/FMA:7197"/>
#           <rdf:li rdf:resource="http://identifiers.org/bto/BTO:0000575"/>
#           <rdf:li rdf:resource="http://identifiers.org/fma/FMA:14515"/>
#         </rdf:Bag>
#       </bqbiol:is>
#       <bqbiol:isVersionOf>
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/pw/PW:0000042"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.pathway/map00052"/>
#           <rdf:li rdf:resource="http://identifiers.org/smpdb/SMP00043"/>
#           <rdf:li rdf:resource="http://identifiers.org/go/GO:0019388"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome/REACTOME:R-HSA-70370.1"/>
#           <rdf:li rdf:resource="http://identifiers.org/metacyc/PWY-6317"/>
#         </rdf:Bag>
#       </bqbiol:isVersionOf>
#     </rdf:Description>
#   </rdf:RDF>
# </annotation><listOfUnitDefinitions>
#   <unitDefinition id="Pa_s_per_m2">
#     <listOfUnits>
#       <unit kind="pascal" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="-2" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="Pa_s_per_m3">
#     <listOfUnits>
#       <unit kind="pascal" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="-3" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="Pa_s_per_m4">
#     <listOfUnits>
#       <unit kind="pascal" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="-4" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="Pa">
#     <listOfUnits>
#       <unit kind="pascal" exponent="1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m_per_s">
#     <listOfUnits>
#       <unit kind="metre" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="per_m3">
#     <listOfUnits>
#       <unit kind="metre" exponent="-3" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="per_m2">
#     <listOfUnits>
#       <unit kind="metre" exponent="-2" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="mole_per_s">
#     <listOfUnits>
#       <unit kind="mole" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m2_per_s">
#     <listOfUnits>
#       <unit kind="metre" exponent="2" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="mole_per_s_per_mM2">
#     <listOfUnits>
#       <unit kind="mole" exponent="-1" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="6" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m3_per_skg">
#     <listOfUnits>
#       <unit kind="metre" exponent="3" scale="0" multiplier="1"/>
#       <unit kind="kilogram" exponent="-1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m2">
#     <listOfUnits>
#       <unit kind="metre" exponent="2" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="mM_s">
#     <listOfUnits>
#       <unit kind="mole" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="-3" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="per_s">
#     <listOfUnits>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m3">
#     <listOfUnits>
#       <unit kind="metre" exponent="3" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="mM">
#     <listOfUnits>
#       <unit kind="mole" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="-3" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="mole_per_s_per_mM">
#     <listOfUnits>
#       <unit kind="metre" exponent="3" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="kg_per_m3">
#     <listOfUnits>
#       <unit kind="kilogram" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="-3" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="per_mM">
#     <listOfUnits>
#       <unit kind="metre" exponent="3" scale="0" multiplier="1"/>
#       <unit kind="mole" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m6_per_Pa2_s2">
#     <listOfUnits>
#       <unit kind="pascal" exponent="-2" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-2" scale="0" multiplier="1"/>
#       <unit kind="metre" exponent="6" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="kg">
#     <listOfUnits>
#       <unit kind="kilogram" exponent="1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m">
#     <listOfUnits>
#       <unit kind="metre" exponent="1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="s">
#     <listOfUnits>
#       <unit kind="second" exponent="1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="Pa_s">
#     <listOfUnits>
#       <unit kind="pascal" exponent="1" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
#   <unitDefinition id="m3_per_s">
#     <listOfUnits>
#       <unit kind="metre" exponent="3" scale="0" multiplier="1"/>
#       <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#     </listOfUnits>
#   </unitDefinition>
# </listOfUnitDefinitions><listOfCompartments>
#   <compartment metaid="meta_8019070b1f7b4c09ad4da10f0fde620c" sboTerm="SBO:0000290" id="h" name="hepatocyte" spatialDimensions="3" units="m3" constant="false">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_8019070b1f7b4c09ad4da10f0fde620c">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000290"/>
#               <rdf:li rdf:resource="http://identifiers.org/go/GO:0005623"/>
#               <rdf:li rdf:resource="http://identifiers.org/fma/FMA:68646"/>
#               <rdf:li rdf:resource="http://identifiers.org/bto/BTO:0000575"/>
#               <rdf:li rdf:resource="http://identifiers.org/fma/FMA:14515"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </compartment>
#   <compartment metaid="meta_1958dffb94194727a92f679394f3f70b" sboTerm="SBO:0000290" id="c" name="cytosol" spatialDimensions="3" units="m3" constant="false">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_1958dffb94194727a92f679394f3f70b">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000290"/>
#               <rdf:li rdf:resource="http://identifiers.org/go/GO:0005829"/>
#               <rdf:li rdf:resource="http://identifiers.org/fma/FMA:66836"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </compartment>
#   <compartment metaid="meta_29dd2d33d9d441ffb2c9ff009cdc53ab" sboTerm="SBO:0000290" id="e" name="external" spatialDimensions="3" units="m3" constant="false">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_29dd2d33d9d441ffb2c9ff009cdc53ab">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000290"/>
#               <rdf:li rdf:resource="http://identifiers.org/go/GO:0005615"/>
#               <rdf:li rdf:resource="http://identifiers.org/fma/FMA:70022"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </compartment>
#   <compartment metaid="meta_95bdbc79a6cc4947add0cd3814ad548f" sboTerm="SBO:0000290" id="m" name="plasma membrane" spatialDimensions="2" units="m2" constant="false">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_95bdbc79a6cc4947add0cd3814ad548f">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000290"/>
#               <rdf:li rdf:resource="http://identifiers.org/go/GO:0005886"/>
#               <rdf:li rdf:resource="http://identifiers.org/fma/FMA:63841"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </compartment>
# </listOfCompartments><listOfSpecies>
#   <species metaid="meta_efdd4281d5ab4602ab61f10489563714" sboTerm="SBO:0000247" id="c__ppi" name="pyrophosphate" compartment="c" initialConcentration="0.008" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-3" fbc:chemicalFormula="HO7P2">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_efdd4281d5ab4602ab61f10489563714">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:33019"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00013"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_064337aaff75438f9c6e66708b9327b3" sboTerm="SBO:0000247" id="e__h2oM" name="water M*" compartment="e" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="H2O">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_064337aaff75438f9c6e66708b9327b3">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15377"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00001"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_fde14a11edf0423ea984db294e25314e" sboTerm="SBO:0000247" id="c__glc1p" name="D-glucose 1-phophate" compartment="c" initialConcentration="0.012" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-2" fbc:chemicalFormula="C6H11O9P">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_fde14a11edf0423ea984db294e25314e">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:58601"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00103"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_bfcdf23753454b13bad898a95073a0e4" sboTerm="SBO:0000247" id="c__acptgal" name="Acceptor-galactose" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="true" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H1206R">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_bfcdf23753454b13bad898a95073a0e4">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_2f56b36d4003431f83d9c899b876f3d2" sboTerm="SBO:0000247" id="c__acpt" name="Acceptor (glc/gal)" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="true" constant="false" fbc:charge="0" fbc:chemicalFormula="H2R">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_2f56b36d4003431f83d9c899b876f3d2">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_0374aacdb6dd4a0291ff1ee1093578f8" sboTerm="SBO:0000247" id="c__udpgal" name="UDP-D-galactose" compartment="c" initialConcentration="0.11" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-2" fbc:chemicalFormula="C15H22N2O17P2">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_0374aacdb6dd4a0291ff1ee1093578f8">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:66914"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00052"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_f002dcb5802d4bbeb59cc72f6fb6fad6" sboTerm="SBO:0000247" id="c__udp" name="UDP" compartment="c" initialConcentration="0.09" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-3" fbc:chemicalFormula="C9H11N2O12P2">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_f002dcb5802d4bbeb59cc72f6fb6fad6">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:58223"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00015"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_3548925b52684e39baf39c3ab49a6c17" sboTerm="SBO:0000247" id="c__atp" name="ATP" compartment="c" initialConcentration="2.7" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-4" fbc:chemicalFormula="C10H12N5O13P3">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_3548925b52684e39baf39c3ab49a6c17">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:30616"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00002"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_4d14a91d44894ae8870c9a9c3a605a42" sboTerm="SBO:0000247" id="c__utp" name="UTP" compartment="c" initialConcentration="0.27" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-4" fbc:chemicalFormula="C9H11N2O15P3">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_4d14a91d44894ae8870c9a9c3a605a42">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:46398"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00075"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_b323baba1940418cabe69d6102ec7049" sboTerm="SBO:0000247" id="e__gal" name="D-galactose" compartment="e" initialConcentration="0.00012" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H12O6">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_b323baba1940418cabe69d6102ec7049">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:28061"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00124"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_3616e25a6d24462495bda5e5ffff82db" sboTerm="SBO:0000247" id="c__gal1pM" name="D-galactose 1-phosphate M*" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-2" fbc:chemicalFormula="C6H11O9P">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_3616e25a6d24462495bda5e5ffff82db">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:58336"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00446"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_8439b4b83f2b4de0b14d0170fcf1e63e" sboTerm="SBO:0000247" id="c__gal" name="D-galactose" compartment="c" initialConcentration="0.00012" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H12O6">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_8439b4b83f2b4de0b14d0170fcf1e63e">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:28061"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00124"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_c125fac91335438e8d788e6fa0ec5596" sboTerm="SBO:0000247" id="c__acptgalM" name="Acceptor-galactose M*" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="true" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H1206R">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_c125fac91335438e8d788e6fa0ec5596">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_db0a6dc0caef47288e7e6d7f33f9dd7c" sboTerm="SBO:0000247" id="c__acptglc" name="Acceptor-glucose" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="true" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H1206R">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_db0a6dc0caef47288e7e6d7f33f9dd7c">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_5355794a52014a4a91f366587865dd46" sboTerm="SBO:0000247" id="c__galtolM" name="D-galactitol M*" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H14O6">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_5355794a52014a4a91f366587865dd46">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:16813"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C01697"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_8125235f167941bfb422fa1a22b40df9" sboTerm="SBO:0000247" id="e__galM" name="D-galactose M*" compartment="e" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H12O6">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_8125235f167941bfb422fa1a22b40df9">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:28061"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00124"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_33994d88f60846b0871326eb5cea9915" sboTerm="SBO:0000247" id="c__o2" name="O2" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="true" constant="false" fbc:charge="0" fbc:chemicalFormula="O2">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_33994d88f60846b0871326eb5cea9915">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15379"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00007"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_a9273a0059114fe284793eb90b7822b3" sboTerm="SBO:0000247" id="c__glc6p" name="D-glucose 6-phosphate" compartment="c" initialConcentration="0.12" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-2" fbc:chemicalFormula="C6H11O9P">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_a9273a0059114fe284793eb90b7822b3">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:58225"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00668"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_f427fa859876474cb3322d7ff04c706a" sboTerm="SBO:0000247" id="c__adp" name="ADP" compartment="c" initialConcentration="1.2" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-3" fbc:chemicalFormula="C10H12N5O10P2">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_f427fa859876474cb3322d7ff04c706a">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:456216"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00008"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_c38dfa291ae344c39c402c8a1cc95444" sboTerm="SBO:0000247" id="h__h2oM" name="water M*" compartment="h" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="H2O">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_c38dfa291ae344c39c402c8a1cc95444">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15377"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00001"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_04f01a2dd69540b5a1b50851e98a5f28" sboTerm="SBO:0000247" id="c__co2" name="CO2" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="true" constant="false" fbc:charge="0" fbc:chemicalFormula="CO2">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_04f01a2dd69540b5a1b50851e98a5f28">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:16526"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00011"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_43915904d9c94e4089ce4ed8348e88cd" sboTerm="SBO:0000247" id="c__nadp" name="NADP" compartment="c" initialConcentration="0.1" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-3" fbc:chemicalFormula="C21H25N7O17P3">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_43915904d9c94e4089ce4ed8348e88cd">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:58349"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00006"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_0ed5af3561fd4d098c134bea86b6ecf5" sboTerm="SBO:0000247" id="c__hydron" name="H+" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="true" constant="false" fbc:charge="1" fbc:chemicalFormula="H">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_0ed5af3561fd4d098c134bea86b6ecf5">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15378"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00080"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_9a495c2a5bda47628bfd72052b994ab6" sboTerm="SBO:0000247" id="c__udpgalM" name="UDP-D-galactose M*" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-2" fbc:chemicalFormula="C15H22N2O17P2">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_9a495c2a5bda47628bfd72052b994ab6">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:66914"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00052"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_16eabf5ebf964da5a3b15ad64541693e" sboTerm="SBO:0000247" id="c__galM" name="D-galactose M*" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H12O6">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_16eabf5ebf964da5a3b15ad64541693e">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:28061"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00124"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_2509ac114ca743dba944cec70f21eec6" sboTerm="SBO:0000247" id="c__galtol" name="D-galactitol" compartment="c" initialConcentration="0.001" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="0" fbc:chemicalFormula="C6H14O6">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_2509ac114ca743dba944cec70f21eec6">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:16813"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C01697"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_6759631feb0f4de1a34ee9cbb39354ee" sboTerm="SBO:0000247" id="c__nadph" name="NADPH" compartment="c" initialConcentration="0.1" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-4" fbc:chemicalFormula="C21H26N7O17P3">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_6759631feb0f4de1a34ee9cbb39354ee">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57783"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00005"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_164938efca3b4d1f8124cf2004112d2e" sboTerm="SBO:0000247" id="c__glc6pM" name="D-glucose 6-phosphate M*" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-2" fbc:chemicalFormula="C6H11O9P">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_164938efca3b4d1f8124cf2004112d2e">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:58225"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:isVersionOf>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00668"/>
#             </rdf:Bag>
#           </bqbiol:isVersionOf>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#   </species>
#   <species metaid="meta_b509d01aed704110b38e84a3d5cadaa9" sboTerm="SBO:0000247" id="c__glc1pM" name="D-glucose 1-phophate M*" compartment="c" initialConcentration="0" substanceUnits="mole" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false" fbc:charge="-2" fbc:chemicalFormula="C6H11O9P">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_b509d01aed704110b38e84a3d5cadaa9">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000247"/>
#               <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:58601"/>
#               <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00103"/>
#             </rdf:Bag>
# ...
#   <reaction metaid="meta_80e4587df06e4491bb49c00baba86cee" sboTerm="SBO:0000176" id="c__GLY" name="Glycolysis [c__]" reversible="true" fast="false" compartment="c">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_80e4587df06e4491bb49c00baba86cee">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000176"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="c__glc6p" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__o2" stoichiometry="5" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__phos" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__co2" stoichiometry="6" constant="true"/>
#       <speciesReference species="c__h2o" stoichiometry="5" constant="true"/>
#     </listOfProducts>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <divide/>
#           <apply>
#             <times/>
#             <apply>
#               <divide/>
#               <ci> c__GLY_Vmax </ci>
#               <ci> GLY_k_glc6p </ci>
#             </apply>
#             <apply>
#               <minus/>
#               <ci> c__glc6p </ci>
#               <ci> GLY_k_glc6p </ci>
#             </apply>
#             <ci> c__phos </ci>
#           </apply>
#           <apply>
#             <plus/>
#             <ci> c__phos </ci>
#             <ci> GLY_k_p </ci>
#           </apply>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_2ffff1a8dfbe47978eb0c0b29b51d833" sboTerm="SBO:0000176" id="c__GLYM" name="Glycolysis M [c__]" reversible="false" fast="false" compartment="c">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_2ffff1a8dfbe47978eb0c0b29b51d833">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000176"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="c__glc6pM" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__o2" stoichiometry="5" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__phos" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__co2" stoichiometry="6" constant="true"/>
#       <speciesReference species="c__h2o" stoichiometry="5" constant="true"/>
#     </listOfProducts>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <divide/>
#           <apply>
#             <times/>
#             <apply>
#               <divide/>
#               <ci> c__GLY_Vmax </ci>
#               <ci> GLY_k_glc6p </ci>
#             </apply>
#             <ci> c__glc6pM </ci>
#             <ci> c__phos </ci>
#           </apply>
#           <apply>
#             <plus/>
#             <ci> c__phos </ci>
#             <ci> GLY_k_p </ci>
#           </apply>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_2588b3fcbc5242009aed294124505ef8" sboTerm="SBO:0000176" id="c__GTFGAL" name="Glycosyltransferase galactose [c__]" reversible="false" fast="false" compartment="c">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_2588b3fcbc5242009aed294124505ef8">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000176"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="c__udpgal" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acpt" stoichiometry="1" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__udp" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acptgal" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__hydron" stoichiometry="1" constant="true"/>
#     </listOfProducts>
#     <listOfModifiers>
#       <modifierSpeciesReference species="c__udpgalM"/>
#     </listOfModifiers>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <times/>
#           <apply>
#             <divide/>
#             <ci> c__udpgal </ci>
#             <ci> c__udpgal_tot </ci>
#           </apply>
#           <ci> c__GTFGAL_Vf </ci>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_f92f3195da2e47dea7a92303308c7eb9" sboTerm="SBO:0000176" id="c__GTFGALM" name="Glycosyltransferase galactose M [c__]" reversible="false" fast="false" compartment="c">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_f92f3195da2e47dea7a92303308c7eb9">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000176"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="c__udpgalM" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acpt" stoichiometry="1" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__udp" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acptgalM" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__hydron" stoichiometry="1" constant="true"/>
#     </listOfProducts>
#     <listOfModifiers>
#       <modifierSpeciesReference species="c__udpgal"/>
#     </listOfModifiers>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <times/>
#           <apply>
#             <divide/>
#             <ci> c__udpgalM </ci>
#             <ci> c__udpgal_tot </ci>
#           </apply>
#           <ci> c__GTFGAL_Vf </ci>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_61342956f3574adb9e3a9cc494be1400" sboTerm="SBO:0000176" id="c__GTFGLC" name="Glycosyltransferase glucose [c__]" reversible="false" fast="false" compartment="c">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_61342956f3574adb9e3a9cc494be1400">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000176"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="c__udpglc" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acpt" stoichiometry="1" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__udp" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acptglc" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__hydron" stoichiometry="1" constant="true"/>
#     </listOfProducts>
#     <listOfModifiers>
#       <modifierSpeciesReference species="c__udpglcM"/>
#     </listOfModifiers>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <times/>
#           <apply>
#             <divide/>
#             <ci> c__udpglc </ci>
#             <ci> c__udpglc_tot </ci>
#           </apply>
#           <ci> c__GTFGLC_Vf </ci>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_c1911f9eabb94f59b58e51e7a2b63d1e" sboTerm="SBO:0000176" id="c__GTFGLCM" name="Glycosyltransferase glucose M [c__]" reversible="false" fast="false" compartment="c">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_c1911f9eabb94f59b58e51e7a2b63d1e">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000176"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="c__udpglcM" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acpt" stoichiometry="1" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__udp" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__acptglcM" stoichiometry="1" constant="true"/>
#       <speciesReference species="c__hydron" stoichiometry="1" constant="true"/>
#     </listOfProducts>
#     <listOfModifiers>
#       <modifierSpeciesReference species="c__udpglc"/>
#     </listOfModifiers>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <times/>
#           <apply>
#             <divide/>
#             <ci> c__udpglcM </ci>
#             <ci> c__udpglc_tot </ci>
#           </apply>
#           <ci> c__GTFGLC_Vf </ci>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_854c41f0aa124d20bb921e2c5cd08961" sboTerm="SBO:0000185" id="e__H2OTM" name="H2O M transport [e__]" reversible="true" fast="false" compartment="m">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_854c41f0aa124d20bb921e2c5cd08961">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000185"/>
#             </rdf:Bag>
#           </bqbiol:is>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="e__h2oM" stoichiometry="1" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="h__h2oM" stoichiometry="1" constant="true"/>
#     </listOfProducts>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <times/>
#           <apply>
#             <divide/>
#             <ci> c__H2OT_Vmax </ci>
#             <ci> H2OT_k </ci>
#           </apply>
#           <apply>
#             <minus/>
#             <ci> e__h2oM </ci>
#             <ci> h__h2oM </ci>
#           </apply>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_de93f7d298c14b0e925beba94ec97a33" sboTerm="SBO:0000185" id="e__GLUT2_GAL" name="galactose transport [e__]" reversible="true" fast="false" compartment="m">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_de93f7d298c14b0e925beba94ec97a33">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000185"/>
#               <rdf:li rdf:resource="http://identifiers.org/uniprot/P11168"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:hasProperty>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/omim/OMIM:227810"/>
#             </rdf:Bag>
#           </bqbiol:hasProperty>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="e__gal" stoichiometry="1" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__gal" stoichiometry="1" constant="true"/>
#     </listOfProducts>
#     <listOfModifiers>
#       <modifierSpeciesReference species="e__galM"/>
#       <modifierSpeciesReference species="c__galM"/>
#     </listOfModifiers>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <times/>
#           <ci> c__GLUT2_V </ci>
#           <apply>
#             <minus/>
#             <ci> e__gal </ci>
#             <ci> c__gal </ci>
#           </apply>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
#   <reaction metaid="meta_8f62557025314386b22db994450fa032" sboTerm="SBO:0000185" id="e__GLUT2_GALM" name="galactose transport M [e__]" reversible="true" fast="false" compartment="m">
#     <annotation>
#       <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:vCard="http://www.w3.org/2001/vcard-rdf/3.0#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/" xmlns:bqmodel="http://biomodels.net/model-qualifiers/">
#         <rdf:Description rdf:about="#meta_8f62557025314386b22db994450fa032">
#           <bqbiol:is>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/biomodels.sbo/SBO:0000185"/>
#               <rdf:li rdf:resource="http://identifiers.org/uniprot/P11168"/>
#             </rdf:Bag>
#           </bqbiol:is>
#           <bqbiol:hasProperty>
#             <rdf:Bag>
#               <rdf:li rdf:resource="http://identifiers.org/omim/227810"/>
#             </rdf:Bag>
#           </bqbiol:hasProperty>
#         </rdf:Description>
#       </rdf:RDF>
#     </annotation>
#     <listOfReactants>
#       <speciesReference species="e__galM" stoichiometry="1" constant="true"/>
#     </listOfReactants>
#     <listOfProducts>
#       <speciesReference species="c__galM" stoichiometry="1" constant="true"/>
#     </listOfProducts>
#     <listOfModifiers>
#       <modifierSpeciesReference species="e__gal"/>
#       <modifierSpeciesReference species="c__gal"/>
#     </listOfModifiers>
#     <kineticLaw>
#       <math xmlns="http://www.w3.org/1998/Math/MathML">
#         <apply>
#           <times/>
#           <ci> c__GLUT2_V </ci>
#           <apply>
#             <minus/>
#             <ci> e__galM </ci>
#             <ci> c__galM </ci>
#           </apply>
#         </apply>
#       </math>
#     </kineticLaw>
#   </reaction>
# </listOfReactions>
# </model>
# </sbml>

# %% [markdown]
# ## Double parameter variability

# %%
# get units from the sbml
import libsbml
doc = libsbml.readSBML(comp_model.filepath)
sbml_model = doc.getModel()
units = {}
for pid in const_parameter_ids: 
    p = sbml_model.getParameter(pid)
    unit = p.getUnits()
    units[pid] = unit
units
# Out:
# {'ALDR_f': 'dimensionless',
#  'ALDR_k_gal': 'mM',
#  'ALDR_k_galtol': 'mM',
#  'ALDR_k_nadp': 'mM',
#  'ALDR_k_nadph': 'mM',
#  'ALDR_keq': 'dimensionless',
#  'ATPS_f': 'dimensionless',
#  'ATPS_k_adp': 'mM',
#  'ATPS_k_atp': 'mM',
#  'ATPS_k_phos': 'mM',
#  'ATPS_keq': 'per_mM',
#  'A_m': 'm2',
#  'GALE_PA': 's',
#  'GALE_f': 'dimensionless',
#  'GALE_k_udpgal': 'mM',
#  'GALE_k_udpglc': 'mM',
#  'GALE_kcat': 'per_s',
#  'GALE_keq': 'dimensionless',
#  'GALK_PA': 'mole',
#  'GALK_k_adp': 'mM',
#  'GALK_k_atp': 'mM',
#  'GALK_k_gal': 'mM',
#  'GALK_k_gal1p': 'mM',
#  'GALK_kcat': 'per_s',
#  'GALK_keq': 'dimensionless',
#  'GALK_ki_gal1p': 'mM',
#  'GALT_f': 'dimensionless',
#  'GALT_k_gal1p': 'mM',
#  'GALT_k_glc1p': 'mM',
#  'GALT_k_udpgal': 'mM',
#  'GALT_k_udpglc': 'mM',
#  'GALT_keq': 'dimensionless',
#  'GALT_ki_udp': 'mM',
#  'GALT_ki_utp': 'mM',
#  'GALT_vm': 'dimensionless',
#  'GLUT2_f': 'mole_per_s',
#  'GLUT2_k_gal': 'mM',
#  'GLY_f': 'dimensionless',
#  'GLY_k_glc6p': 'mM',
#  'GLY_k_p': 'mM',
#  'GTF_f': 'dimensionless',
#  'GTF_k_udpgal': 'mM',
#  'GTF_k_udpglc': 'mM',
#  'H2OT_f': 'mole_per_s',
#  'H2OT_k': 'mM',
#  'IMP_f': 'dimensionless',
#  'IMP_k_gal1p': 'mM',
#  'NADPR_f': 'dimensionless',
#  'NADPR_k_nadp': 'mM',
#  'NADPR_keq': 'dimensionless',
#  'NADPR_ki_nadph': 'mM',
#  'NDKU_f': 'dimensionless',
#  'NDKU_k_adp': 'mM',
#  'NDKU_k_atp': 'mM',
#  'NDKU_k_udp': 'mM',
#  'NDKU_k_utp': 'mM',
#  'NDKU_keq': 'dimensionless',
#  'Nf': 'dimensionless',
#  'PGM1_f': 'dimensionless',
#  'PGM1_k_glc1p': 'mM',
#  'PGM1_k_glc6p': 'mM',
#  'PGM1_keq': 'dimensionless',
#  'PPASE_f': 'dimensionless',
#  'PPASE_k_ppi': 'mM',
#  'PPASE_n': 'dimensionless',
#  'REF_P': 'mM',
#  'UGALP_f': 'dimensionless',
#  'UGP_f': 'dimensionless',
#  'UGP_k_gal1p': 'mM',
#  'UGP_k_glc1p': 'mM',
#  'UGP_k_ppi': 'mM',
#  'UGP_k_udpgal': 'mM',
#  'UGP_k_udpglc': 'mM',
#  'UGP_k_utp': 'mM',
#  'UGP_keq': 'dimensionless',
#  'UGP_ki_udpglc': 'mM',
#  'UGP_ki_utp': 'mM',
#  'Vol_c': 'm3',
#  'Vol_e': 'm3',
#  'Vol_h': 'm3',
#  'c__ALDR_P': 'mM',
#  'c__ATPS_P': 'mM',
#  'c__GALE_P': 'mM',
#  'c__GALK_P': 'mM',
#  'c__GALT_P': 'mM',
#  'c__GLUT2_P': 'mM',
#  'c__GLY_P': 'mM',
#  'c__GTF_P': 'mM',
#  'c__IMP_P': 'mM',
#  'c__NADPR_P': 'mM',
#  'c__NDKU_P': 'mM',
#  'c__PGM1_P': 'mM',
#  'c__PPASE_P': 'mM',
#  'c__UGP_P': 'mM',
#  'deficiency': 'dimensionless',
#  'f_cyto': 'dimensionless',
#  'f_tissue': 'dimensionless',
#  'scale_f': 'per_m3',
#  'x_cell': 'm',
#  'y_cell': 'm'}

# %%
# get the original values for all parameters
values = {pid: r[pid] for pid in parameter_ids}

# %%
# now we can setup the single variations
from multiscale.odesim.dist.samples import Sample, SampleParameter
factors = [0.90, 1.10]
samples = []
for pid in parameter_ids:
    for f in factors:
        # create an empty sample
        s = Sample()
        # Set the parameters to the values
        sp = SampleParameter(pid, f * r[pid], unit=units[pid], \
                             parameter_type=db_api.ParameterType.GLOBAL_PARAMETER)
        s.add_parameter(sp)
        samples.append(s)

samples
# Out:
# [{'scale_f': <scale_f = 2.790E-01 [per_m3] (GLOBAL_PARAMETER)>},
#  {'scale_f': <scale_f = 3.410E-01 [per_m3] (GLOBAL_PARAMETER)>},
#  {'y_cell': <y_cell = 9.306E-06 [m] (GLOBAL_PARAMETER)>},
#  {'y_cell': <y_cell = 1.137E-05 [m] (GLOBAL_PARAMETER)>},
#  {'x_cell': <x_cell = 2.250E-05 [m] (GLOBAL_PARAMETER)>},
#  {'x_cell': <x_cell = 2.750E-05 [m] (GLOBAL_PARAMETER)>},
#  {'f_cyto': <f_cyto = 3.600E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'f_cyto': <f_cyto = 4.400E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'Nf': <Nf = 9.000E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'Nf': <Nf = 1.100E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'deficiency': <deficiency = 0.000E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'deficiency': <deficiency = 0.000E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'REF_P': <REF_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'REF_P': <REF_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'f_tissue': <f_tissue = 7.200E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'f_tissue': <f_tissue = 8.800E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'Vol_e': <Vol_e = 5.816E-15 [m3] (GLOBAL_PARAMETER)>},
#  {'Vol_e': <Vol_e = 7.109E-15 [m3] (GLOBAL_PARAMETER)>},
#  {'Vol_c': <Vol_c = 2.327E-15 [m3] (GLOBAL_PARAMETER)>},
#  {'Vol_c': <Vol_c = 2.844E-15 [m3] (GLOBAL_PARAMETER)>},
#  {'A_m': <A_m = 5.625E-10 [m2] (GLOBAL_PARAMETER)>},
#  {'A_m': <A_m = 6.875E-10 [m2] (GLOBAL_PARAMETER)>},
#  {'Vol_h': <Vol_h = 5.816E-15 [m3] (GLOBAL_PARAMETER)>},
#  {'Vol_h': <Vol_h = 7.109E-15 [m3] (GLOBAL_PARAMETER)>},
#  {'GALK_PA': <GALK_PA = 2.160E-02 [mole] (GLOBAL_PARAMETER)>},
#  {'GALK_PA': <GALK_PA = 2.640E-02 [mole] (GLOBAL_PARAMETER)>},
#  {'GALK_keq': <GALK_keq = 4.500E+01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALK_keq': <GALK_keq = 5.500E+01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALK_k_gal1p': <GALK_k_gal1p = 1.350E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_k_gal1p': <GALK_k_gal1p = 1.650E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_k_adp': <GALK_k_adp = 7.200E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_k_adp': <GALK_k_adp = 8.800E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_ki_gal1p': <GALK_ki_gal1p = 4.770E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_ki_gal1p': <GALK_ki_gal1p = 5.830E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_kcat': <GALK_kcat = 7.830E+00 [per_s] (GLOBAL_PARAMETER)>},
#  {'GALK_kcat': <GALK_kcat = 9.570E+00 [per_s] (GLOBAL_PARAMETER)>},
#  {'GALK_k_gal': <GALK_k_gal = 1.260E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_k_gal': <GALK_k_gal = 1.540E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_k_atp': <GALK_k_atp = 3.060E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'GALK_k_atp': <GALK_k_atp = 3.740E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GALK_P': <c__GALK_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GALK_P': <c__GALK_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'IMP_f': <IMP_f = 4.500E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'IMP_f': <IMP_f = 5.500E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'IMP_k_gal1p': <IMP_k_gal1p = 3.150E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'IMP_k_gal1p': <IMP_k_gal1p = 3.850E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__IMP_P': <c__IMP_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__IMP_P': <c__IMP_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_f': <ATPS_f = 9.000E+01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'ATPS_f': <ATPS_f = 1.100E+02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'ATPS_keq': <ATPS_keq = 5.220E-01 [per_mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_keq': <ATPS_keq = 6.380E-01 [per_mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_k_adp': <ATPS_k_adp = 9.000E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_k_adp': <ATPS_k_adp = 1.100E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_k_atp': <ATPS_k_atp = 4.500E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_k_atp': <ATPS_k_atp = 5.500E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_k_phos': <ATPS_k_phos = 9.000E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'ATPS_k_phos': <ATPS_k_phos = 1.100E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__ATPS_P': <c__ATPS_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__ATPS_P': <c__ATPS_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_f': <ALDR_f = 9.000E+05 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'ALDR_f': <ALDR_f = 1.100E+06 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'ALDR_keq': <ALDR_keq = 3.600E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'ALDR_keq': <ALDR_keq = 4.400E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_gal': <ALDR_k_gal = 3.600E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_gal': <ALDR_k_gal = 4.400E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_galtol': <ALDR_k_galtol = 3.600E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_galtol': <ALDR_k_galtol = 4.400E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_nadp': <ALDR_k_nadp = 9.000E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_nadp': <ALDR_k_nadp = 1.100E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_nadph': <ALDR_k_nadph = 9.000E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'ALDR_k_nadph': <ALDR_k_nadph = 1.100E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_P': <c__ALDR_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_P': <c__ALDR_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'NADPR_f': <NADPR_f = 9.000E-11 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NADPR_f': <NADPR_f = 1.100E-10 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NADPR_keq': <NADPR_keq = 9.000E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NADPR_keq': <NADPR_keq = 1.100E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NADPR_k_nadp': <NADPR_k_nadp = 1.350E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'NADPR_k_nadp': <NADPR_k_nadp = 1.650E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'NADPR_ki_nadph': <NADPR_ki_nadph = 9.000E-03 [mM] (GLOBAL_PARAMETER)>},
#  {'NADPR_ki_nadph': <NADPR_ki_nadph = 1.100E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'c__NADPR_P': <c__NADPR_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__NADPR_P': <c__NADPR_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_f': <GALT_f = 9.000E-03 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALT_f': <GALT_f = 1.100E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALT_keq': <GALT_keq = 9.000E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALT_keq': <GALT_keq = 1.100E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALT_k_glc1p': <GALT_k_glc1p = 3.330E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_k_glc1p': <GALT_k_glc1p = 4.070E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_k_udpgal': <GALT_k_udpgal = 4.500E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_k_udpgal': <GALT_k_udpgal = 5.500E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_ki_utp': <GALT_ki_utp = 1.170E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_ki_utp': <GALT_ki_utp = 1.430E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_ki_udp': <GALT_ki_udp = 3.150E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_ki_udp': <GALT_ki_udp = 3.850E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_vm': <GALT_vm = 7.236E+02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALT_vm': <GALT_vm = 8.844E+02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALT_k_gal1p': <GALT_k_gal1p = 1.125E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_k_gal1p': <GALT_k_gal1p = 1.375E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_k_udpglc': <GALT_k_udpglc = 3.870E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALT_k_udpglc': <GALT_k_udpglc = 4.730E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GALT_P': <c__GALT_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GALT_P': <c__GALT_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GALE_f': <GALE_f = 2.700E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALE_f': <GALE_f = 3.300E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALE_PA': <GALE_PA = 2.502E-02 [s] (GLOBAL_PARAMETER)>},
#  {'GALE_PA': <GALE_PA = 3.058E-02 [s] (GLOBAL_PARAMETER)>},
#  {'GALE_kcat': <GALE_kcat = 3.240E+01 [per_s] (GLOBAL_PARAMETER)>},
#  {'GALE_kcat': <GALE_kcat = 3.960E+01 [per_s] (GLOBAL_PARAMETER)>},
#  {'GALE_keq': <GALE_keq = 2.970E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALE_keq': <GALE_keq = 3.630E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GALE_k_udpglc': <GALE_k_udpglc = 6.210E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'GALE_k_udpglc': <GALE_k_udpglc = 7.590E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'GALE_k_udpgal': <GALE_k_udpgal = 2.700E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GALE_k_udpgal': <GALE_k_udpgal = 3.300E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GALE_P': <c__GALE_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GALE_P': <c__GALE_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_f': <UGP_f = 1.800E+03 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'UGP_f': <UGP_f = 2.200E+03 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'UGP_keq': <UGP_keq = 4.050E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'UGP_keq': <UGP_keq = 4.950E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'UGP_k_utp': <UGP_k_utp = 5.067E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_utp': <UGP_k_utp = 6.193E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_glc1p': <UGP_k_glc1p = 1.548E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_glc1p': <UGP_k_glc1p = 1.892E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_udpglc': <UGP_k_udpglc = 4.410E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_udpglc': <UGP_k_udpglc = 5.390E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_ppi': <UGP_k_ppi = 1.494E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_ppi': <UGP_k_ppi = 1.826E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_gal1p': <UGP_k_gal1p = 4.500E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_gal1p': <UGP_k_gal1p = 5.500E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_udpgal': <UGP_k_udpgal = 3.780E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_k_udpgal': <UGP_k_udpgal = 4.620E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_ki_utp': <UGP_ki_utp = 5.787E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_ki_utp': <UGP_ki_utp = 7.073E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_ki_udpglc': <UGP_ki_udpglc = 5.787E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'UGP_ki_udpglc': <UGP_ki_udpglc = 7.073E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__UGP_P': <c__UGP_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__UGP_P': <c__UGP_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'UGALP_f': <UGALP_f = 9.000E-03 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'UGALP_f': <UGALP_f = 1.100E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PPASE_f': <PPASE_f = 4.500E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PPASE_f': <PPASE_f = 5.500E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PPASE_k_ppi': <PPASE_k_ppi = 6.300E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'PPASE_k_ppi': <PPASE_k_ppi = 7.700E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'PPASE_n': <PPASE_n = 3.600E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PPASE_n': <PPASE_n = 4.400E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__PPASE_P': <c__PPASE_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__PPASE_P': <c__PPASE_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_f': <NDKU_f = 1.800E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NDKU_f': <NDKU_f = 2.200E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NDKU_keq': <NDKU_keq = 9.000E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NDKU_keq': <NDKU_keq = 1.100E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_atp': <NDKU_k_atp = 1.197E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_atp': <NDKU_k_atp = 1.463E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_adp': <NDKU_k_adp = 3.780E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_adp': <NDKU_k_adp = 4.620E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_utp': <NDKU_k_utp = 2.430E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_utp': <NDKU_k_utp = 2.970E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_udp': <NDKU_k_udp = 1.710E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'NDKU_k_udp': <NDKU_k_udp = 2.090E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__NDKU_P': <c__NDKU_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__NDKU_P': <c__NDKU_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'PGM1_f': <PGM1_f = 4.500E+01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PGM1_f': <PGM1_f = 5.500E+01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PGM1_keq': <PGM1_keq = 9.000E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PGM1_keq': <PGM1_keq = 1.100E+01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'PGM1_k_glc6p': <PGM1_k_glc6p = 6.030E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'PGM1_k_glc6p': <PGM1_k_glc6p = 7.370E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'PGM1_k_glc1p': <PGM1_k_glc1p = 4.050E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'PGM1_k_glc1p': <PGM1_k_glc1p = 4.950E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_P': <c__PGM1_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_P': <c__PGM1_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GLY_f': <GLY_f = 9.000E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GLY_f': <GLY_f = 1.100E-01 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GLY_k_glc6p': <GLY_k_glc6p = 1.080E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GLY_k_glc6p': <GLY_k_glc6p = 1.320E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GLY_k_p': <GLY_k_p = 1.800E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GLY_k_p': <GLY_k_p = 2.200E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GLY_P': <c__GLY_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GLY_P': <c__GLY_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GTF_f': <GTF_f = 1.800E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GTF_f': <GTF_f = 2.200E-02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'GTF_k_udpgal': <GTF_k_udpgal = 9.000E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'GTF_k_udpgal': <GTF_k_udpgal = 1.100E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'GTF_k_udpglc': <GTF_k_udpglc = 9.000E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'GTF_k_udpglc': <GTF_k_udpglc = 1.100E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GTF_P': <c__GTF_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GTF_P': <c__GTF_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'H2OT_f': <H2OT_f = 7.200E+00 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'H2OT_f': <H2OT_f = 8.800E+00 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'H2OT_k': <H2OT_k = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'H2OT_k': <H2OT_k = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'GLUT2_f': <GLUT2_f = 1.530E+01 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'GLUT2_f': <GLUT2_f = 1.870E+01 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'GLUT2_k_gal': <GLUT2_k_gal = 2.502E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'GLUT2_k_gal': <GLUT2_k_gal = 3.058E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GLUT2_P': <c__GLUT2_P = 9.000E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GLUT2_P': <c__GLUT2_P = 1.100E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'c__gal_tot': <c__gal_tot = 4.992E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__gal_tot': <c__gal_tot = 6.101E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'e__gal_tot': <e__gal_tot = 6.384E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'e__gal_tot': <e__gal_tot = 7.803E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__udpglc_tot': <c__udpglc_tot = 1.710E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__udpglc_tot': <c__udpglc_tot = 2.091E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__adp_bal': <c__adp_bal = 3.510E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'c__adp_bal': <c__adp_bal = 4.290E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'c__phos_bal': <c__phos_bal = 1.579E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__phos_bal': <c__phos_bal = 1.929E+01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__glc6p_tot': <c__glc6p_tot = 1.226E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__glc6p_tot': <c__glc6p_tot = 1.498E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__gal1p_tot': <c__gal1p_tot = 9.873E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__gal1p_tot': <c__gal1p_tot = 1.207E+00 [mM] (GLOBAL_PARAMETER)>},
#  {'c__scale': <c__scale = 1.803E-15 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__scale': <c__scale = 2.204E-15 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__galtol_tot': <c__galtol_tot = 8.426E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'c__galtol_tot': <c__galtol_tot = 1.030E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__glc1p_tot': <c__glc1p_tot = 1.305E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'c__glc1p_tot': <c__glc1p_tot = 1.596E-02 [mM] (GLOBAL_PARAMETER)>},
#  {'c__udpgal_tot': <c__udpgal_tot = 2.655E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__udpgal_tot': <c__udpgal_tot = 3.245E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__udp_bal': <c__udp_bal = 7.290E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__udp_bal': <c__udp_bal = 8.910E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__nadp_bal': <c__nadp_bal = 1.800E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__nadp_bal': <c__nadp_bal = 2.200E-01 [mM] (GLOBAL_PARAMETER)>},
#  {'c__GALK_V': <c__GALK_V = 1.627E-16 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__GALK_V': <c__GALK_V = 1.988E-16 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__GALK_Vb': <c__GALK_Vb = 4.269E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALK_Vb': <c__GALK_Vb = 5.217E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALK_Vmax': <c__GALK_Vmax = 3.765E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALK_Vmax': <c__GALK_Vmax = 4.601E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALK_dm': <c__GALK_dm = 3.626E+02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__GALK_dm': <c__GALK_dm = 4.432E+02 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__GALK_Vf': <c__GALK_Vf = 2.439E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALK_Vf': <c__GALK_Vf = 2.981E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__IMP_dm': <c__IMP_dm = 3.721E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__IMP_dm': <c__IMP_dm = 4.548E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__IMP_Vf': <c__IMP_Vf = 1.427E-17 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__IMP_Vf': <c__IMP_Vf = 1.744E-17 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__IMP_Vmax': <c__IMP_Vmax = 1.882E-17 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__IMP_Vmax': <c__IMP_Vmax = 2.301E-17 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ATPS_Vmax': <c__ATPS_Vmax = 3.765E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ATPS_Vmax': <c__ATPS_Vmax = 4.601E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_Vb': <c__ALDR_Vb = 1.399E-13 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_Vb': <c__ALDR_Vb = 1.710E-13 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_V': <c__ALDR_V = 3.115E-11 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_V': <c__ALDR_V = 3.807E-11 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_Vmax': <c__ALDR_Vmax = 3.765E-10 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_Vmax': <c__ALDR_Vmax = 4.601E-10 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_dm': <c__ALDR_dm = 2.720E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_dm': <c__ALDR_dm = 3.324E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_Vf': <c__ALDR_Vf = 1.399E-13 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__ALDR_Vf': <c__ALDR_Vf = 1.710E-13 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__NADPR_Vmax': <c__NADPR_Vmax = 3.765E-20 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__NADPR_Vmax': <c__NADPR_Vmax = 4.601E-20 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALT_Vf': <c__GALT_Vf = 1.643E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALT_Vf': <c__GALT_Vf = 2.008E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALT_V': <c__GALT_V = 7.878E-16 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__GALT_V': <c__GALT_V = 9.629E-16 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__GALT_Vmax': <c__GALT_Vmax = 3.027E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALT_Vmax': <c__GALT_Vmax = 3.699E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALT_Vb': <c__GALT_Vb = 3.371E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALT_Vb': <c__GALT_Vb = 4.121E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALT_dm': <c__GALT_dm = 6.433E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__GALT_dm': <c__GALT_dm = 7.863E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__GALE_Vb': <c__GALE_Vb = 3.091E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALE_Vb': <c__GALE_Vb = 3.778E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALE_V': <c__GALE_V = 3.458E-16 [mole_per_s_per_mM] (GLOBAL_PARAMETER)>},
#  {'c__GALE_V': <c__GALE_V = 4.226E-16 [mole_per_s_per_mM] (GLOBAL_PARAMETER)>},
#  {'c__GALE_Vmax': <c__GALE_Vmax = 1.130E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALE_Vmax': <c__GALE_Vmax = 1.382E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALE_dm': <c__GALE_dm = 4.264E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__GALE_dm': <c__GALE_dm = 5.212E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__GALE_Vf': <c__GALE_Vf = 6.571E-17 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GALE_Vf': <c__GALE_Vf = 8.032E-17 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGP_Vf': <c__UGP_Vf = 3.421E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGP_Vf': <c__UGP_Vf = 4.182E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGP_V': <c__UGP_V = 1.047E-12 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__UGP_V': <c__UGP_V = 1.280E-12 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__UGP_Vmax': <c__UGP_Vmax = 7.529E-13 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGP_Vmax': <c__UGP_Vmax = 9.203E-13 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGP_dm': <c__UGP_dm = 6.683E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__UGP_dm': <c__UGP_dm = 8.168E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__UGP_Vb': <c__UGP_Vb = 3.503E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGP_Vb': <c__UGP_Vb = 4.281E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGALP_Vb': <c__UGALP_Vb = 1.870E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGALP_Vb': <c__UGALP_Vb = 2.286E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGALP_V': <c__UGALP_V = 3.602E-16 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__UGALP_V': <c__UGALP_V = 4.403E-16 [mole_per_s_per_mM2] (GLOBAL_PARAMETER)>},
#  {'c__UGALP_Vf': <c__UGALP_Vf = 8.902E-17 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__UGALP_Vf': <c__UGALP_Vf = 1.088E-16 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PPASE_Vmax': <c__PPASE_Vmax = 3.765E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PPASE_Vmax': <c__PPASE_Vmax = 4.601E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__NDKU_Vmax': <c__NDKU_Vmax = 1.506E-12 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__NDKU_Vmax': <c__NDKU_Vmax = 1.841E-12 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_Vb': <c__PGM1_Vb = 3.735E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_Vb': <c__PGM1_Vb = 4.565E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_V': <c__PGM1_V = 2.742E-13 [mole_per_s_per_mM] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_V': <c__PGM1_V = 3.351E-13 [mole_per_s_per_mM] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_Vmax': <c__PGM1_Vmax = 1.882E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_Vmax': <c__PGM1_Vmax = 2.301E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_dm': <c__PGM1_dm = 1.373E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_dm': <c__PGM1_dm = 1.678E+00 [dimensionless] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_Vf': <c__PGM1_Vf = 3.977E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__PGM1_Vf': <c__PGM1_Vf = 4.861E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GLY_Vmax': <c__GLY_Vmax = 1.882E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GLY_Vmax': <c__GLY_Vmax = 2.301E-15 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GTFGAL_Vf': <c__GTFGAL_Vf = 5.623E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GTFGAL_Vf': <c__GTFGAL_Vf = 6.873E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GTF_Vmax': <c__GTF_Vmax = 7.529E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GTF_Vmax': <c__GTF_Vmax = 9.203E-18 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GTFGLC_Vf': <c__GTFGLC_Vf = 0.000E+00 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GTFGLC_Vf': <c__GTFGLC_Vf = 0.000E+00 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__H2OT_Vmax': <c__H2OT_Vmax = 1.442E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__H2OT_Vmax': <c__H2OT_Vmax = 1.763E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GLUT2_V': <c__GLUT2_V = 1.055E-15 [mole_per_s_per_mM] (GLOBAL_PARAMETER)>},
#  {'c__GLUT2_V': <c__GLUT2_V = 1.289E-15 [mole_per_s_per_mM] (GLOBAL_PARAMETER)>},
#  {'c__GLUT2_Vmax': <c__GLUT2_Vmax = 3.065E-14 [mole_per_s] (GLOBAL_PARAMETER)>},
#  {'c__GLUT2_Vmax': <c__GLUT2_Vmax = 3.746E-14 [mole_per_s] (GLOBAL_PARAMETER)>}]

# %%
# We want step based integration in the interval [0.0, 20.0]
settings_dict = {db_api.SettingKey.VAR_STEPS: False,\
                 db_api.SettingKey.T_START: 0.0,\
                 db_api.SettingKey.T_END: 20.0, \
                 db_api.SettingKey.STEPS: 100}

# For the tolerances, ... we use the default settings
settings = db_api.create_settings(settings_dict)
for setting in settings:
    print(setting)
# Out:
# INTEGRATOR = ROADRUNNER
# VAR_STEPS = False
# ABS_TOL = 1e-06
# REL_TOL = 1e-06
# T_START = 0.0
# T_END = 20.0
# STEPS = 100
# STIFF = True

# %%
method = db_api.create_method(method_type=db_api.MethodType.ODE, settings=settings)

# %%
task = db_api.create_task(comp_model, method=method, info="Single parameter variation {}.".format(factors))

# %%
from django.core.exceptions import ValidationError
try:
    # add the simulations to the task
    simulations = db_tools.create_simulations_from_samples(task, samples)
    # finalize task, so no additional simulations can be added
    task.finalize_status()
except ValidationError:
    simulations = task.simulations.all()
simulations
print('TaskStatus:', task.status_str)
# Out:
# TaskStatus: FINALIZED

# %%
len(simulations)
# Out:
# 320

# %% [markdown]
# ### Solve the ODE system
#
# Now we are running the solver on the defined problems.

# %%
from multiscale.odesim.simulate import solve

# %%
solve.run_simulations(simulations, task)
# Out:
# Loading : /home/mkoenig/multiscale-galactose-results/django/model/galactose_30_annotated.xml
# SBML load time: 0.156955003738
# Time: [0.0206|0.0004]
# Time: [0.0131|0.0005]
# Time: [0.0125|0.0005]
# Time: [0.0115|0.0004]
# Time: [0.0151|0.0006]
# Time: [0.0140|0.0005]
# Time: [0.0129|0.0005]
# Time: [0.0116|0.0005]
# Time: [0.0133|0.0004]
# Time: [0.0139|0.0006]
# Time: [0.0130|0.0005]
# Time: [0.0121|0.0005]
# Time: [0.0151|0.0005]
# Time: [0.0121|0.0005]
# Time: [0.0117|0.0005]
# Time: [0.0114|0.0004]
# Time: [0.0129|0.0005]
# Time: [0.0144|0.0005]
# Time: [0.0158|0.0008]
# Time: [0.0140|0.0006]
# Time: [0.0128|0.0005]
# Time: [0.0118|0.0005]
# Time: [0.0114|0.0005]
# Time: [0.0132|0.0005]
# Time: [0.0140|0.0005]
# Time: [0.0131|0.0005]
# Time: [0.0127|0.0005]
# Time: [0.0111|0.0005]
# Time: [0.0123|0.0004]
# Time: [0.0136|0.0005]
# Time: [0.0128|0.0005]
# Time: [0.0144|0.0005]
# Time: [0.0140|0.0006]
# Time: [0.0129|0.0004]
# Time: [0.0138|0.0006]
# Time: [0.0141|0.0005]
# Time: [0.0131|0.0006]
# Time: [0.0134|0.0005]
# Time: [0.0139|0.0005]
# Time: [0.0143|0.0005]
# Time: [0.0139|0.0006]
# Time: [0.0126|0.0005]
# Time: [0.0137|0.0005]
# Time: [0.0138|0.0006]
# Time: [0.0134|0.0006]
# Time: [0.0132|0.0005]
# Time: [0.0131|0.0005]
# Time: [0.0142|0.0006]
# Time: [0.0126|0.0005]
# Time: [0.0138|0.0006]
# Time: [0.0127|0.0005]
# Time: [0.0135|0.0005]
# Time: [0.0132|0.0006]
# Time: [0.0141|0.0005]
# Time: [0.0137|0.0005]
# Time: [0.0138|0.0005]
# Time: [0.0134|0.0006]
# Time: [0.0139|0.0005]
# Time: [0.0140|0.0005]
# Time: [0.0141|0.0006]
# Time: [0.0141|0.0007]
# Time: [0.0133|0.0006]
# Time: [0.0139|0.0005]
# Time: [0.0144|0.0008]
# Time: [0.0118|0.0005]
# Time: [0.0140|0.0005]
# Time: [0.0134|0.0005]
# Time: [0.0136|0.0005]
# Time: [0.0145|0.0006]
# Time: [0.0154|0.0007]
# Time: [0.0144|0.0007]
# Time: [0.0149|0.0006]
# Time: [0.0124|0.0005]
# Time: [0.0134|0.0005]
# Time: [0.0137|0.0005]
# Time: [0.0134|0.0006]
# Time: [0.0136|0.0005]
# Time: [0.0130|0.0006]
# Time: [0.0140|0.0005]
# Time: [0.0130|0.0005]
# Time: [0.0131|0.0005]
# Time: [0.0127|0.0005]
# Time: [0.0129|0.0005]
# Time: [0.0131|0.0005]
# Time: [0.0118|0.0005]
# Time: [0.0122|0.0005]
# Time: [0.0127|0.0005]
# Time: [0.0124|0.0006]
# Time: [0.0122|0.0005]
# Time: [0.0115|0.0005]
# Time: [0.0135|0.0004]
# Time: [0.0129|0.0004]
# Time: [0.0123|0.0005]
# Time: [0.0120|0.0005]
# Time: [0.0112|0.0005]
# Time: [0.0128|0.0005]
# Time: [0.0134|0.0005]
# Time: [0.0130|0.0005]
# Time: [0.0130|0.0005]
# Time: [0.0130|0.0006]
# Time: [0.0134|0.0005]
# Time: [0.0147|0.0006]
# Time: [0.0132|0.0005]
# Time: [0.0122|0.0005]
# Time: [0.0139|0.0006]
# Time: [0.0131|0.0005]
# Time: [0.0143|0.0006]
# Time: [0.0127|0.0004]
# Time: [0.0132|0.0005]
# Time: [0.0128|0.0005]
# Time: [0.0118|0.0005]
# Time: [0.0142|0.0005]
# Time: [0.0138|0.0005]
# Time: [0.0124|0.0005]
# Time: [0.0116|0.0005]
# Time: [0.0132|0.0005]
# Time: [0.0135|0.0005]
# Time: [0.0124|0.0005]
# Time: [0.0117|0.0005]
# Time: [0.0132|0.0005]
# Time: [0.0136|0.0005]
# Time: [0.0128|0.0005]
# Time: [0.0129|0.0006]
# Time: [0.0126|0.0006]
# Time: [0.0126|0.0005]
# Time: [0.0130|0.0005]
# Time: [0.0127|0.0005]
# Time: [0.0128|0.0006]
# Time: [0.0121|0.0005]
# Time: [0.0133|0.0005]
# Time: [0.0136|0.0005]
# Time: [0.0135|0.0006]
# Time: [0.0131|0.0005]
# Time: [0.0126|0.0005]
# Time: [0.0140|0.0006]
# Time: [0.0135|0.0005]
# Time: [0.0117|0.0004]
# Time: [0.0120|0.0005]
# Time: [0.0141|0.0006]
# Time: [0.0119|0.0004]
# Time: [0.0139|0.0005]
# Time: [0.0116|0.0004]
# Time: [0.0126|0.0005]
# Time: [0.0133|0.0006]
# Time: [0.0120|0.0004]
# Time: [0.0148|0.0006]
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2524, in _simulate
#     def _simulate(self, *args): return _roadrunner.RoadRunner__simulate(self, *args)
# RuntimeError: CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 112, in _solve_roadrunner_single
#     variableStep=True, stiff=True)
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 2962, in simulate
#     result = self._simulate(o)
# ...
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__PGM1_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__PGM1_dm, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__PGM1_dm, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__PGM1_Vf, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__PGM1_Vf, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GLY_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GLY_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GTFGAL_Vf, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GTFGAL_Vf, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GTF_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GTF_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GTFGLC_Vf, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GTFGLC_Vf, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__H2OT_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__H2OT_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GLUT2_V, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GLUT2_V, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GLUT2_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------
# ------------------------------------------------------------
# *** Exception in ODE integration ***
# Traceback (most recent call last):
#   File "/home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/odesim/simulate/solve_ode.py", line 82, in _solve_roadrunner_single
#     rr.model[name] = p.value
#   File "/usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.py", line 1802, in __setitem__
#     def __setitem__(self, *args): return _roadrunner.ExecutableModel___setitem__(self, *args)
# RuntimeError: could not set value for c__GLUT2_Vmax, it is defined by an assignment rule, can not be set independently., at int rrllvm::LLVMExecutableModel::setValues(bool (*)(rrllvm::LLVMModelData*, int, double), rrllvm::LLVMExecutableModel::GetNameFuncPtr, int, const int*, const double*)
# ------------------------------------------------------------

# %%
# plot the results
from simapp.models import Result
import matplotlib.pylab as plt
plt_fontsize = 30

# %%
# Load the HDF5 files and plot them
from multiscale.odesim.simulate import solve_io
reload(solve_io)
plt.figure(figsize=(20,14))
for sim in simulations:
    result = Result.objects.get(simulation=sim, result_type=db_api.ResultType.HDF5)
    data, header = solve_io.load_hdf5(result.filepath)
    plt.plot(data[:,0], data[:,1:], '-', color='black')
    
plt.xlabel('time [s]', fontsize=plt_fontsize)
plt.ylabel('species [mM]', fontsize=plt_fontsize);

# %% [markdown]
# ## Double parameter variation
#
# For comparison all double parameter changes in the model are performed.
# How much larger are the combined effects of parameter changes?

# %%
# now we can setup the double variations
from multiscale.odesim.dist.samples import Sample, SampleParameter
samples_double = []
for pid1 in parameter_ids:
    for pid2 in parameter_ids:
        if pid1 == pid2:
            continue
        for f1 in factors:
            for f2 in factors:
        
                # create an empty sample
                s = Sample()
                # Set first parameter
                sp1 = SampleParameter(pid1, f1 * rr[pid1], unit=units[pid1], \
                             parameter_type=db_api.ParameterType.GLOBAL_PARAMETER)
                # Set second parameter
                sp2 = SampleParameter(pid2, f2 * rr[pid2], unit=units[pid2], \
                             parameter_type=db_api.ParameterType.GLOBAL_PARAMETER)
                s.add_parameters([sp1, sp2])
                samples_double.append(s)
print('Number of parameters:', len(parameter_ids))                
print('Number of samples:', len(samples_double))

# %%
task_double = db_api.create_task(comp_model, method=method, info="Double parameter variation {}.".format(factors))

# %%
# Removing objects from the database
# from simapp.models import Task
# task_temp = Task.objects.get(pk=64)
# task_temp.delete()
# task_double.info = "Double parameter variation {}.".format(factors)
# task_double.save()

# %%
print('TaskStatus:', task.status_str)
from django.core.exceptions import ValidationError
try:
    # add the simulations to the task
    simulations_double = db_tools.create_simulations_from_samples(task_double, samples_double)
    # finalize task, so no additional simulations can be added
    task_double.finalize_status()
except ValidationError:
    simulations_double = task_double.simulations.all()
simulations
print('TaskStatus:', task.status_str)

# %%
import time
start = time.time()
solve.run_simulations(simulations_double, task_double)
duration = time.time() - start
print('Total time:', duration)

# %%
# Load the HDF5 files and plot them
from multiscale.odesim.simulate import solve_io
reload(solve_io)
plt.figure(figsize=(20,14))
for sim in simulations_double:
    result = Result.objects.get(simulation=sim, result_type=db_api.ResultType.HDF5)
    data, header = solve_io.load_hdf5(result.filepath)
    plt.plot(data[:,0], data[:,1:], '-', color='grey')
    
for sim in simulations:
    result = Result.objects.get(simulation=sim, result_type=db_api.ResultType.HDF5)
    data, header = solve_io.load_hdf5(result.filepath)
    plt.plot(data[:,0], data[:,1:], '-', color='black')
    
plt.xlabel('time [s]', fontsize=plt_fontsize)
plt.ylabel('species [mM]', fontsize=plt_fontsize)
