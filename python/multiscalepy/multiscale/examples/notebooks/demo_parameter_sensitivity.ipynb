# %% [markdown]
# # Variability analysis
#
# Analyse the effect of parameter changes and double parameter changes on the output of given simulation.
# All parameters are changed and the effects on the simulation results/stability is analysed.

# %%
from __future__ import print_function
# import and setup database
import django
django.setup()
# import the database API functions and tools
import simapp.db.api as db_api
import multiscale.simulate.db.tools as db_tools

# %%
# create model in database
from multiscale.examples.testdata import demo_sbml
print(demo_sbml)
comp_model = db_api.create_model(filepath=demo_sbml)
# Out:
# /home/mkoenig/git/multiscale-galactose/python/multiscalepy/multiscale/examples/models/demo/Koenig_demo_10_annotated.xml

# %%
comp_model
# Out:
# <CompModel: <SBML: Koenig_demo_10_annotated>>

# %%
import roadrunner
roadrunner.getVersionStr()
# Out:
# '1.4.2; Compiler: gcc 4.8.4, C++ version: 199711; JIT Compiler: LLVM-3.4; Date: Feb  1 2016, 15:48:52; LibSBML Version: 5.12.0'

# %%
# %matplotlib inline
import multiscale.simulate.roadrunner_tools as rt

# Uset the filepath from the database
r = rt.MyRunner(comp_model.filepath)
r.selections = ['time'] + ['[{}]'.format(s) for s in r.model.getFloatingSpeciesIds()]
print(r.selections)
r.set_integrator_settings()
s = r.simulate(0, 20)  # timecourse for 20 [s]
r.plot()
# Out:
# Time<__init__> SBML compile: 0.0941150188446 [s]
# ['time', '[e__A]', '[e__C]', '[e__B]', '[c__C]', '[c__B]', '[c__A]']
# Time<simulate> : 0.00259900093079 [s]

# %% [markdown]
# ## Parameter variability analysis
#
# Vary all single parameters in the model between [0.95-1.05] the original value.

# %%
# These are the parameters to vary
parameter_ids = r.model.getGlobalParameterIds()
sorted(parameter_ids)
# Out:
# ['Keq_v1',
#  'Keq_v4',
#  'Km_A',
#  'Km_B',
#  'Km_C',
#  'Vmax_bA',
#  'Vmax_bB',
#  'Vmax_bC',
#  'Vmax_v1',
#  'Vmax_v2',
#  'Vmax_v3',
#  'Vmax_v4',
#  'scale_f']

# %%
# get values for all parameters
values = {pid: r[pid] for pid in parameter_ids}
# print(values)

# get units from SBML file
import libsbml
doc = libsbml.readSBML(demo_sbml)
sbml_model = doc.getModel()
units = {}
for pid in parameter_ids: 
    p = sbml_model.getParameter(pid)
    unit = p.getUnits()
    units[pid] = (r[pid], unit)
for k,v in units.iteritems():
    print(k, '=', v)
# Out:
# Vmax_v4 = (0.5, 'mole_per_s')
# scale_f = (1e-06, 'dimensionless')
# Vmax_bB = (2.0, 'mole_per_s')
# Vmax_bC = (2.0, 'mole_per_s')
# Vmax_bA = (5.0, 'mole_per_s')
# Vmax_v2 = (0.5, 'mole_per_s')
# Vmax_v3 = (0.5, 'mole_per_s')
# Vmax_v1 = (1.0, 'mole_per_s')
# Km_A = (1.0, 'mM')
# Km_C = (3.0, 'mM')
# Km_B = (0.5, 'mM')
# Keq_v4 = (2.0, 'dimensionless')
# Keq_v1 = (10.0, 'dimensionless')

# %%
# now we can setup the single variations
from multiscale.simulate.dist.samples import Sample, SampleParameter
factors = [0.90, 1.10]
samples = []
for pid in parameter_ids:
    for f in factors:
        # create an empty sample
        s = Sample()
        # Set the parameters to the values
        sp = SampleParameter(pid, f * r[pid], unit=units[pid], \
                             parameter_type=db_api.ParameterType.GLOBAL_PARAMETER)
        s.add_parameter(sp)
        samples.append(s)

samples
# Out:
# [{'Km_C': <Km_C = 2.700E+00 [(3.0, 'mM')] (GLOBAL_PARAMETER)>},
#  {'Km_C': <Km_C = 3.300E+00 [(3.0, 'mM')] (GLOBAL_PARAMETER)>},
#  {'scale_f': <scale_f = 9.000E-07 [(1e-06, 'dimensionless')] (GLOBAL_PARAMETER)>},
#  {'scale_f': <scale_f = 1.100E-06 [(1e-06, 'dimensionless')] (GLOBAL_PARAMETER)>},
#  {'Vmax_bB': <Vmax_bB = 1.800E+00 [(2.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_bB': <Vmax_bB = 2.200E+00 [(2.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_bC': <Vmax_bC = 1.800E+00 [(2.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_bC': <Vmax_bC = 2.200E+00 [(2.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_bA': <Vmax_bA = 4.500E+00 [(5.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_bA': <Vmax_bA = 5.500E+00 [(5.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v2': <Vmax_v2 = 4.500E-01 [(0.5, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v2': <Vmax_v2 = 5.500E-01 [(0.5, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v3': <Vmax_v3 = 4.500E-01 [(0.5, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v3': <Vmax_v3 = 5.500E-01 [(0.5, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v1': <Vmax_v1 = 9.000E-01 [(1.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v1': <Vmax_v1 = 1.100E+00 [(1.0, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Km_A': <Km_A = 9.000E-01 [(1.0, 'mM')] (GLOBAL_PARAMETER)>},
#  {'Km_A': <Km_A = 1.100E+00 [(1.0, 'mM')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v4': <Vmax_v4 = 4.500E-01 [(0.5, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Vmax_v4': <Vmax_v4 = 5.500E-01 [(0.5, 'mole_per_s')] (GLOBAL_PARAMETER)>},
#  {'Km_B': <Km_B = 4.500E-01 [(0.5, 'mM')] (GLOBAL_PARAMETER)>},
#  {'Km_B': <Km_B = 5.500E-01 [(0.5, 'mM')] (GLOBAL_PARAMETER)>},
#  {'Keq_v4': <Keq_v4 = 1.800E+00 [(2.0, 'dimensionless')] (GLOBAL_PARAMETER)>},
#  {'Keq_v4': <Keq_v4 = 2.200E+00 [(2.0, 'dimensionless')] (GLOBAL_PARAMETER)>},
#  {'Keq_v1': <Keq_v1 = 9.000E+00 [(10.0, 'dimensionless')] (GLOBAL_PARAMETER)>},
#  {'Keq_v1': <Keq_v1 = 1.100E+01 [(10.0, 'dimensionless')] (GLOBAL_PARAMETER)>}]

# %%
# We want step based integration in the interval [0.0, 20.0]
# TODO: synchronize the possible settings
settings_dict = {db_api.SettingKey.VAR_STEPS: False,\
                 db_api.SettingKey.T_START: 0.0,\
                 db_api.SettingKey.T_END: 20.0, \
                 db_api.SettingKey.STEPS: 100}

# For the tolerances, ... we use the default settings
settings = db_api.create_settings(settings_dict)
for setting in settings:
    print(setting)
# Out:
# INTEGRATOR = ROADRUNNER
# VAR_STEPS = False
# ABS_TOL = 1e-06
# REL_TOL = 1e-06
# T_START = 0.0
# T_END = 20.0
# STEPS = 100
# STIFF = True

# %%
method = db_api.create_method(method_type=db_api.MethodType.ODE, settings=settings)
print(method)
# Out:
# M274

# %%
task = db_api.create_task(comp_model, method=method, info="Single parameter variation {}.".format(factors))
print(task)
print(task.status_str)
# Out:
# T222
# FINALIZED

# %%
from django.core.exceptions import ValidationError

# add the simulations to the task
if task.has_status_open():
    simulations = db_tools.create_simulations_from_samples(task, samples)
    # finalize task, so no additional simulations can be added
    task.finalize_status()
else:
    simulations = task.simulations.all()

print(simulations)
print('TaskStatus:', task.status_str)
# Out:
# [<Simulation: S317>, <Simulation: S316>, <Simulation: S315>, <Simulation: S314>, <Simulation: S313>, <Simulation: S312>, <Simulation: S311>, <Simulation: S310>, <Simulation: S309>, <Simulation: S308>, <Simulation: S307>, <Simulation: S306>, <Simulation: S305>, <Simulation: S304>, <Simulation: S303>, <Simulation: S302>, <Simulation: S301>, <Simulation: S300>, <Simulation: S299>, <Simulation: S298>, '...(remaining elements truncated)...']
# TaskStatus: FINALIZED

# %%
len(simulations)
# Out:
# 26

# %% [markdown]
# ### Solve the ODE system
#
# Now we are running the solver on the defined problems.

# %%
from multiscale.simulate import solve

# %%
solve.run_simulations(simulations, task)
# Out:
# Time<__init__> SBML compile: 0.0479249954224 [s]
# Time<simulate> : 0.00148582458496 [s]
# Time: [0.0163|0.0015]
# Time<simulate> : 0.00156712532043 [s]
# Time: [0.0130|0.0016]
# Time<simulate> : 0.00185298919678 [s]
# Time: [0.0142|0.0019]
# Time<simulate> : 0.00229811668396 [s]
# Time: [0.0144|0.0028]
# Time<simulate> : 0.00151085853577 [s]
# Time: [0.0119|0.0015]
# Time<simulate> : 0.00180196762085 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00154399871826 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.00154900550842 [s]
# Time: [0.0130|0.0020]
# Time<simulate> : 0.00171399116516 [s]
# Time: [0.0124|0.0018]
# Time<simulate> : 0.00162506103516 [s]
# Time: [0.0120|0.0017]
# Time<simulate> : 0.00155282020569 [s]
# Time: [0.0135|0.0016]
# Time<simulate> : 0.00193500518799 [s]
# Time: [0.0148|0.0023]
# Time<simulate> : 0.00185394287109 [s]
# Time: [0.0141|0.0019]
# Time<simulate> : 0.00154805183411 [s]
# Time: [0.0122|0.0016]
# Time<simulate> : 0.00224208831787 [s]
# Time: [0.0154|0.0023]
# Time<simulate> : 0.0018310546875 [s]
# Time: [0.0122|0.0019]
# Time<simulate> : 0.00161695480347 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.0019850730896 [s]
# Time: [0.0155|0.0020]
# Time<simulate> : 0.00180196762085 [s]
# Time: [0.0138|0.0018]
# Time<simulate> : 0.00173616409302 [s]
# Time: [0.0136|0.0018]
# Time<simulate> : 0.00189208984375 [s]
# Time: [0.0135|0.0019]
# Time<simulate> : 0.00154113769531 [s]
# Time: [0.0136|0.0016]
# Time<simulate> : 0.00186014175415 [s]
# Time: [0.0150|0.0019]
# Time<simulate> : 0.00145387649536 [s]
# Time: [0.0129|0.0015]
# Time<simulate> : 0.00154399871826 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00188612937927 [s]
# Time: [0.0156|0.0019]

# %%
# plot the results
from simapp.models import Result
import matplotlib.pylab as plt
plt_fontsize = 30

# %%
# Load the HDF5 files and plot them
from multiscale.simulate import solve_io
reload(solve_io)
plt.figure(figsize=(10,7))
for sim in simulations:
    result = Result.objects.get(simulation=sim, result_type=db_api.ResultType.HDF5)
    data, header = solve_io.load_hdf5(result.filepath)
    plt.plot(data[:,0], data[:,1:], '-', color='black')
    
plt.xlabel('time [s]', fontsize=plt_fontsize)
plt.ylabel('species [mM]', fontsize=plt_fontsize);

# %% [markdown]
# ## Double parameter variation
#
# For comparison all double parameter changes in the model are performed.
# How much larger are the combined effects of parameter changes?

# %%
# now we can setup the double variations
from multiscale.simulate.dist.samples import Sample, SampleParameter
samples_double = []
for pid1 in parameter_ids:
    for pid2 in parameter_ids:
        if pid1 == pid2:
            continue
        for f1 in factors:
            for f2 in factors:
        
                # create an empty sample
                s = Sample()
                # Set first parameter
                sp1 = SampleParameter(pid1, f1 * r[pid1], unit=units[pid1], \
                             parameter_type=db_api.ParameterType.GLOBAL_PARAMETER)
                # Set second parameter
                sp2 = SampleParameter(pid2, f2 * r[pid2], unit=units[pid2], \
                             parameter_type=db_api.ParameterType.GLOBAL_PARAMETER)
                s.add_parameters([sp1, sp2])
                samples_double.append(s)
print('Number of parameters:', len(parameter_ids))                
print('Number of samples:', len(samples_double))
# Out:
# Number of parameters: 13
# Number of samples: 624

# %%
task_double = db_api.create_task(comp_model, method=method, info="Double parameter variation {}.".format(factors))

# %%
# Removing objects from the database
# from simapp.models import Task
# task_temp = Task.objects.get(pk=64)
# task_temp.delete()
# task_double.info = "Double parameter variation {}.".format(factors)
# task_double.save()

# %%
print('TaskStatus:', task_double.status_str)
if task_double.has_status_open():
    # add the simulations to the task
    simulations_double = db_tools.create_simulations_from_samples(task_double, samples_double)
    # finalize task, so no additional simulations can be added
    task_double.finalize_status()
else:
    simulations_double = task_double.simulations.all()
print(len(simulations_double))
# Out:
# TaskStatus: FINALIZED
# 624

# %%
import time
start = time.time()
solve.run_simulations(simulations_double, task_double)
duration = time.time() - start
print('Total time:', duration)
# Out:
# Time<__init__> SBML compile: 0.048238992691 [s]
# Time<simulate> : 0.00149917602539 [s]
# Time: [0.0148|0.0015]
# Time<simulate> : 0.00163602828979 [s]
# Time: [0.0146|0.0017]
# Time<simulate> : 0.00151991844177 [s]
# Time: [0.0153|0.0015]
# Time<simulate> : 0.00186681747437 [s]
# Time: [0.0146|0.0023]
# Time<simulate> : 0.00195503234863 [s]
# Time: [0.0142|0.0020]
# Time<simulate> : 0.00168013572693 [s]
# Time: [0.0154|0.0017]
# Time<simulate> : 0.00192880630493 [s]
# Time: [0.0154|0.0020]
# Time<simulate> : 0.00210404396057 [s]
# Time: [0.0173|0.0021]
# Time<simulate> : 0.001797914505 [s]
# Time: [0.0156|0.0018]
# Time<simulate> : 0.00176596641541 [s]
# Time: [0.0155|0.0018]
# Time<simulate> : 0.00184011459351 [s]
# Time: [0.0168|0.0022]
# Time<simulate> : 0.00162315368652 [s]
# Time: [0.0148|0.0017]
# Time<simulate> : 0.00153303146362 [s]
# Time: [0.0174|0.0016]
# Time<simulate> : 0.0016770362854 [s]
# Time: [0.0144|0.0017]
# Time<simulate> : 0.00175404548645 [s]
# Time: [0.0144|0.0018]
# Time<simulate> : 0.00180792808533 [s]
# Time: [0.0138|0.0018]
# Time<simulate> : 0.00199818611145 [s]
# Time: [0.0151|0.0020]
# Time<simulate> : 0.00213813781738 [s]
# Time: [0.0159|0.0022]
# Time<simulate> : 0.00185990333557 [s]
# Time: [0.0138|0.0019]
# Time<simulate> : 0.0018298625946 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00176000595093 [s]
# Time: [0.0145|0.0018]
# Time<simulate> : 0.00197815895081 [s]
# Time: [0.0152|0.0020]
# Time<simulate> : 0.00179600715637 [s]
# Time: [0.0145|0.0018]
# Time<simulate> : 0.0017421245575 [s]
# Time: [0.0141|0.0018]
# Time<simulate> : 0.00202012062073 [s]
# Time: [0.0152|0.0021]
# Time<simulate> : 0.00184893608093 [s]
# Time: [0.0155|0.0019]
# Time<simulate> : 0.00259280204773 [s]
# Time: [0.0144|0.0026]
# Time<simulate> : 0.00152087211609 [s]
# Time: [0.0130|0.0015]
# Time<simulate> : 0.0019519329071 [s]
# Time: [0.0161|0.0020]
# Time<simulate> : 0.0019519329071 [s]
# Time: [0.0141|0.0020]
# Time<simulate> : 0.00170612335205 [s]
# Time: [0.0132|0.0017]
# Time<simulate> : 0.00182294845581 [s]
# Time: [0.0138|0.0019]
# Time<simulate> : 0.00185489654541 [s]
# Time: [0.0139|0.0019]
# Time<simulate> : 0.00188708305359 [s]
# Time: [0.0150|0.0019]
# Time<simulate> : 0.00237798690796 [s]
# Time: [0.0148|0.0024]
# Time<simulate> : 0.00184202194214 [s]
# Time: [0.0148|0.0019]
# Time<simulate> : 0.00286197662354 [s]
# Time: [0.0170|0.0029]
# Time<simulate> : 0.00173306465149 [s]
# Time: [0.0143|0.0021]
# Time<simulate> : 0.00152492523193 [s]
# Time: [0.0143|0.0015]
# Time<simulate> : 0.00200200080872 [s]
# Time: [0.0152|0.0020]
# Time<simulate> : 0.00179100036621 [s]
# Time: [0.0146|0.0018]
# Time<simulate> : 0.00179290771484 [s]
# Time: [0.0141|0.0018]
# Time<simulate> : 0.00178408622742 [s]
# Time: [0.0143|0.0018]
# Time<simulate> : 0.00189089775085 [s]
# Time: [0.0144|0.0019]
# Time<simulate> : 0.0016028881073 [s]
# Time: [0.0140|0.0016]
# Time<simulate> : 0.00167989730835 [s]
# Time: [0.0136|0.0017]
# Time<simulate> : 0.00187420845032 [s]
# Time: [0.0141|0.0019]
# Time<simulate> : 0.00190997123718 [s]
# Time: [0.0157|0.0019]
# Time<simulate> : 0.00180506706238 [s]
# Time: [0.0145|0.0018]
# Time<simulate> : 0.001708984375 [s]
# Time: [0.0150|0.0017]
# Time<simulate> : 0.00177478790283 [s]
# Time: [0.0144|0.0018]
# Time<simulate> : 0.00192189216614 [s]
# Time: [0.0156|0.0019]
# Time<simulate> : 0.0019371509552 [s]
# Time: [0.0162|0.0025]
# Time<simulate> : 0.00177097320557 [s]
# Time: [0.0138|0.0018]
# Time<simulate> : 0.00191402435303 [s]
# Time: [0.0157|0.0019]
# Time<simulate> : 0.00176787376404 [s]
# Time: [0.0159|0.0018]
# Time<simulate> : 0.00146389007568 [s]
# Time: [0.0117|0.0015]
# Time<simulate> : 0.00143814086914 [s]
# Time: [0.0122|0.0015]
# Time<simulate> : 0.00186920166016 [s]
# Time: [0.0141|0.0019]
# Time<simulate> : 0.00181484222412 [s]
# Time: [0.0145|0.0019]
# Time<simulate> : 0.00165104866028 [s]
# Time: [0.0148|0.0017]
# Time<simulate> : 0.00189208984375 [s]
# Time: [0.0145|0.0019]
# Time<simulate> : 0.00224995613098 [s]
# Time: [0.0175|0.0023]
# Time<simulate> : 0.00260591506958 [s]
# Time: [0.0175|0.0031]
# Time<simulate> : 0.00167107582092 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.00217509269714 [s]
# Time: [0.0166|0.0022]
# Time<simulate> : 0.0015549659729 [s]
# Time: [0.0133|0.0016]
# Time<simulate> : 0.00192999839783 [s]
# Time: [0.0139|0.0020]
# Time<simulate> : 0.00192904472351 [s]
# Time: [0.0129|0.0020]
# Time<simulate> : 0.00211477279663 [s]
# Time: [0.0140|0.0021]
# Time<simulate> : 0.00176787376404 [s]
# Time: [0.0145|0.0018]
# Time<simulate> : 0.00205707550049 [s]
# Time: [0.0129|0.0021]
# Time<simulate> : 0.00165295600891 [s]
# Time: [0.0127|0.0017]
# Time<simulate> : 0.00170683860779 [s]
# Time: [0.0129|0.0017]
# Time<simulate> : 0.00156998634338 [s]
# Time: [0.0134|0.0016]
# Time<simulate> : 0.00176596641541 [s]
# Time: [0.0128|0.0018]
# Time<simulate> : 0.00155687332153 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00291705131531 [s]
# Time: [0.0166|0.0030]
# Time<simulate> : 0.00163888931274 [s]
# Time: [0.0126|0.0017]
# Time<simulate> : 0.00181007385254 [s]
# Time: [0.0134|0.0018]
# Time<simulate> : 0.00176405906677 [s]
# Time: [0.0133|0.0018]
# Time<simulate> : 0.0018630027771 [s]
# Time: [0.0144|0.0019]
# Time<simulate> : 0.001797914505 [s]
# Time: [0.0139|0.0018]
# Time<simulate> : 0.00171184539795 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.00151205062866 [s]
# Time: [0.0115|0.0015]
# Time<simulate> : 0.00188803672791 [s]
# Time: [0.0159|0.0019]
# Time<simulate> : 0.0019679069519 [s]
# Time: [0.0141|0.0020]
# Time<simulate> : 0.00153803825378 [s]
# Time: [0.0111|0.0016]
# Time<simulate> : 0.0016188621521 [s]
# Time: [0.0127|0.0017]
# Time<simulate> : 0.00176906585693 [s]
# Time: [0.0141|0.0018]
# Time<simulate> : 0.00193214416504 [s]
# Time: [0.0143|0.0020]
# Time<simulate> : 0.00184679031372 [s]
# Time: [0.0131|0.0019]
# Time<simulate> : 0.00156903266907 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00177192687988 [s]
# Time: [0.0146|0.0018]
# Time<simulate> : 0.00165510177612 [s]
# Time: [0.0127|0.0017]
# Time<simulate> : 0.00190711021423 [s]
# Time: [0.0133|0.0019]
# Time<simulate> : 0.00156688690186 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00187110900879 [s]
# Time: [0.0138|0.0019]
# Time<simulate> : 0.00212693214417 [s]
# Time: [0.0167|0.0022]
# Time<simulate> : 0.00185418128967 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00165200233459 [s]
# Time: [0.0142|0.0017]
# Time<simulate> : 0.00271606445312 [s]
# Time: [0.0178|0.0028]
# Time<simulate> : 0.00178408622742 [s]
# Time: [0.0150|0.0022]
# Time<simulate> : 0.00314211845398 [s]
# Time: [0.0164|0.0032]
# Time<simulate> : 0.00197505950928 [s]
# Time: [0.0145|0.0020]
# Time<simulate> : 0.00205898284912 [s]
# Time: [0.0137|0.0021]
# Time<simulate> : 0.00322389602661 [s]
# Time: [0.0172|0.0033]
# Time<simulate> : 0.00310397148132 [s]
# Time: [0.0163|0.0031]
# Time<simulate> : 0.00186991691589 [s]
# Time: [0.0140|0.0019]
# Time<simulate> : 0.00175404548645 [s]
# Time: [0.0135|0.0022]
# Time<simulate> : 0.00153303146362 [s]
# Time: [0.0113|0.0016]
# Time<simulate> : 0.00175809860229 [s]
# Time: [0.0130|0.0018]
# Time<simulate> : 0.00173878669739 [s]
# Time: [0.0133|0.0018]
# Time<simulate> : 0.00169205665588 [s]
# Time: [0.0132|0.0021]
# Time<simulate> : 0.00165987014771 [s]
# Time: [0.0122|0.0017]
# Time<simulate> : 0.00180697441101 [s]
# Time: [0.0133|0.0018]
# Time<simulate> : 0.00170516967773 [s]
# Time: [0.0140|0.0018]
# Time<simulate> : 0.00185894966125 [s]
# Time: [0.0147|0.0023]
# Time<simulate> : 0.00192594528198 [s]
# Time: [0.0123|0.0020]
# Time<simulate> : 0.00156688690186 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00191903114319 [s]
# Time: [0.0162|0.0019]
# Time<simulate> : 0.00160813331604 [s]
# Time: [0.0129|0.0020]
# Time<simulate> : 0.00173211097717 [s]
# Time: [0.0128|0.0018]
# Time<simulate> : 0.00188302993774 [s]
# Time: [0.0148|0.0019]
# Time<simulate> : 0.00200915336609 [s]
# Time: [0.0157|0.0020]
# Time<simulate> : 0.00179100036621 [s]
# Time: [0.0147|0.0018]
# Time<simulate> : 0.00175809860229 [s]
# Time: [0.0134|0.0018]
# Time<simulate> : 0.00200486183167 [s]
# Time: [0.0146|0.0020]
# Time<simulate> : 0.00171899795532 [s]
# Time: [0.0142|0.0017]
# Time<simulate> : 0.00185394287109 [s]
# Time: [0.0139|0.0019]
# Time<simulate> : 0.00191307067871 [s]
# Time: [0.0142|0.0019]
# Time<simulate> : 0.00189805030823 [s]
# Time: [0.0138|0.0019]
# Time<simulate> : 0.00176787376404 [s]
# Time: [0.0128|0.0018]
# Time<simulate> : 0.001708984375 [s]
# Time: [0.0117|0.0017]
# Time<simulate> : 0.00146794319153 [s]
# Time: [0.0115|0.0015]
# Time<simulate> : 0.00172209739685 [s]
# Time: [0.0127|0.0017]
# Time<simulate> : 0.00175595283508 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00175189971924 [s]
# Time: [0.0125|0.0022]
# Time<simulate> : 0.00181603431702 [s]
# Time: [0.0116|0.0018]
# Time<simulate> : 0.00180292129517 [s]
# Time: [0.0125|0.0018]
# Time<simulate> : 0.00164890289307 [s]
# Time: [0.0119|0.0017]
# Time<simulate> : 0.00163602828979 [s]
# Time: [0.0126|0.0017]
# Time<simulate> : 0.00187802314758 [s]
# Time: [0.0126|0.0019]
# Time<simulate> : 0.00173616409302 [s]
# Time: [0.0122|0.0018]
# Time<simulate> : 0.00174188613892 [s]
# Time: [0.0124|0.0018]
# Time<simulate> : 0.00190091133118 [s]
# Time: [0.0131|0.0019]
# Time<simulate> : 0.00175189971924 [s]
# Time: [0.0131|0.0018]
# Time<simulate> : 0.00146508216858 [s]
# Time: [0.0114|0.0015]
# Time<simulate> : 0.0017991065979 [s]
# Time: [0.0123|0.0018]
# Time<simulate> : 0.00185704231262 [s]
# Time: [0.0140|0.0019]
# Time<simulate> : 0.00171899795532 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.00154900550842 [s]
# Time: [0.0121|0.0016]
# Time<simulate> : 0.00165009498596 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.0017249584198 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00185799598694 [s]
# Time: [0.0133|0.0019]
# Time<simulate> : 0.00188589096069 [s]
# Time: [0.0141|0.0019]
# Time<simulate> : 0.00153398513794 [s]
# Time: [0.0122|0.0016]
# Time<simulate> : 0.00156307220459 [s]
# Time: [0.0128|0.0016]
# Time<simulate> : 0.00170302391052 [s]
# Time: [0.0135|0.0017]
# Time<simulate> : 0.00170183181763 [s]
# Time: [0.0121|0.0017]
# Time<simulate> : 0.00187611579895 [s]
# Time: [0.0139|0.0019]
# Time<simulate> : 0.0016040802002 [s]
# Time: [0.0116|0.0016]
# Time<simulate> : 0.00171709060669 [s]
# Time: [0.0124|0.0017]
# Time<simulate> : 0.00157809257507 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00196313858032 [s]
# Time: [0.0131|0.0020]
# Time<simulate> : 0.0016770362854 [s]
# Time: [0.0130|0.0017]
# Time<simulate> : 0.00176000595093 [s]
# Time: [0.0124|0.0018]
# Time<simulate> : 0.00165796279907 [s]
# Time: [0.0139|0.0017]
# Time<simulate> : 0.00260996818542 [s]
# Time: [0.0153|0.0026]
# Time<simulate> : 0.00158500671387 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00172877311707 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00155591964722 [s]
# Time: [0.0123|0.0016]
# Time<simulate> : 0.00161480903625 [s]
# Time: [0.0125|0.0016]
# Time<simulate> : 0.00265598297119 [s]
# Time: [0.0152|0.0027]
# Time<simulate> : 0.00226283073425 [s]
# Time: [0.0151|0.0023]
# Time<simulate> : 0.00155591964722 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.00202584266663 [s]
# Time: [0.0146|0.0021]
# Time<simulate> : 0.00166392326355 [s]
# Time: [0.0144|0.0017]
# Time<simulate> : 0.00186920166016 [s]
# Time: [0.0140|0.0019]
# Time<simulate> : 0.0015881061554 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00190305709839 [s]
# Time: [0.0134|0.0019]
# Time<simulate> : 0.0018310546875 [s]
# Time: [0.0143|0.0019]
# Time<simulate> : 0.00171113014221 [s]
# Time: [0.0142|0.0017]
# Time<simulate> : 0.00157785415649 [s]
# Time: [0.0196|0.0016]
# Time<simulate> : 0.00208711624146 [s]
# Time: [0.0163|0.0021]
# Time<simulate> : 0.00167489051819 [s]
# Time: [0.0144|0.0017]
# Time<simulate> : 0.00191307067871 [s]
# Time: [0.0141|0.0019]
# Time<simulate> : 0.00200390815735 [s]
# Time: [0.0151|0.0020]
# Time<simulate> : 0.00212097167969 [s]
# Time: [0.0163|0.0022]
# Time<simulate> : 0.00176811218262 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00187611579895 [s]
# Time: [0.0138|0.0019]
# Time<simulate> : 0.00194597244263 [s]
# Time: [0.0145|0.0020]
# Time<simulate> : 0.00193405151367 [s]
# Time: [0.0153|0.0020]
# Time<simulate> : 0.00186800956726 [s]
# Time: [0.0143|0.0019]
# Time<simulate> : 0.00157904624939 [s]
# Time: [0.0136|0.0016]
# Time<simulate> : 0.00184488296509 [s]
# Time: [0.0145|0.0019]
# Time<simulate> : 0.00167298316956 [s]
# Time: [0.0145|0.0017]
# Time<simulate> : 0.00178194046021 [s]
# Time: [0.0146|0.0018]
# Time<simulate> : 0.00160717964172 [s]
# Time: [0.0134|0.0016]
# Time<simulate> : 0.00193905830383 [s]
# Time: [0.0139|0.0020]
# Time<simulate> : 0.00265502929688 [s]
# Time: [0.0173|0.0027]
# Time<simulate> : 0.00185298919678 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00152993202209 [s]
# Time: [0.0127|0.0016]
# Time<simulate> : 0.00168418884277 [s]
# Time: [0.0138|0.0017]
# Time<simulate> : 0.0020649433136 [s]
# Time: [0.0148|0.0021]
# Time<simulate> : 0.00169706344604 [s]
# Time: [0.0148|0.0017]
# Time<simulate> : 0.0015070438385 [s]
# Time: [0.0122|0.0015]
# Time<simulate> : 0.0015869140625 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00162076950073 [s]
# Time: [0.0148|0.0017]
# Time<simulate> : 0.0016758441925 [s]
# Time: [0.0120|0.0017]
# Time<simulate> : 0.00140690803528 [s]
# Time: [0.0128|0.0014]
# Time<simulate> : 0.00168204307556 [s]
# Time: [0.0132|0.0017]
# Time<simulate> : 0.00168013572693 [s]
# Time: [0.0145|0.0017]
# Time<simulate> : 0.001708984375 [s]
# Time: [0.0121|0.0017]
# Time<simulate> : 0.00171113014221 [s]
# Time: [0.0123|0.0018]
# Time<simulate> : 0.00156807899475 [s]
# Time: [0.0120|0.0016]
# Time<simulate> : 0.00160884857178 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00346302986145 [s]
# Time: [0.0156|0.0040]
# Time<simulate> : 0.00170421600342 [s]
# Time: [0.0119|0.0017]
# Time<simulate> : 0.00157380104065 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00183701515198 [s]
# Time: [0.0124|0.0019]
# Time<simulate> : 0.00167798995972 [s]
# Time: [0.0129|0.0017]
# Time<simulate> : 0.00171279907227 [s]
# Time: [0.0138|0.0017]
# Time<simulate> : 0.0018618106842 [s]
# Time: [0.0127|0.0019]
# Time<simulate> : 0.00185203552246 [s]
# Time: [0.0134|0.0019]
# Time<simulate> : 0.0015709400177 [s]
# Time: [0.0136|0.0016]
# Time<simulate> : 0.00179696083069 [s]
# Time: [0.0139|0.0018]
# Time<simulate> : 0.00162506103516 [s]
# Time: [0.0117|0.0017]
# Time<simulate> : 0.0015721321106 [s]
# Time: [0.0133|0.0016]
# Time<simulate> : 0.00160002708435 [s]
# Time: [0.0111|0.0016]
# Time<simulate> : 0.00173401832581 [s]
# Time: [0.0149|0.0018]
# Time<simulate> : 0.00164985656738 [s]
# Time: [0.0115|0.0017]
# Time<simulate> : 0.00154495239258 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00176906585693 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00156593322754 [s]
# Time: [0.0114|0.0016]
# Time<simulate> : 0.00162482261658 [s]
# Time: [0.0132|0.0017]
# Time<simulate> : 0.00169014930725 [s]
# Time: [0.0132|0.0017]
# Time<simulate> : 0.0021870136261 [s]
# Time: [0.0150|0.0022]
# Time<simulate> : 0.00174617767334 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00156712532043 [s]
# Time: [0.0137|0.0016]
# Time<simulate> : 0.00160789489746 [s]
# Time: [0.0139|0.0016]
# Time<simulate> : 0.00171899795532 [s]
# Time: [0.0145|0.0018]
# Time<simulate> : 0.00158190727234 [s]
# Time: [0.0136|0.0016]
# Time<simulate> : 0.00165104866028 [s]
# Time: [0.0134|0.0017]
# Time<simulate> : 0.00187683105469 [s]
# Time: [0.0142|0.0019]
# Time<simulate> : 0.00182199478149 [s]
# Time: [0.0149|0.0019]
# Time<simulate> : 0.00181007385254 [s]
# Time: [0.0143|0.0018]
# Time<simulate> : 0.00163817405701 [s]
# Time: [0.0136|0.0017]
# Time<simulate> : 0.00187206268311 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.0016188621521 [s]
# Time: [0.0142|0.0017]
# Time<simulate> : 0.00187706947327 [s]
# Time: [0.0148|0.0019]
# Time<simulate> : 0.0016040802002 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00184798240662 [s]
# Time: [0.0142|0.0019]
# Time<simulate> : 0.0017409324646 [s]
# Time: [0.0140|0.0018]
# Time<simulate> : 0.00268387794495 [s]
# Time: [0.0171|0.0027]
# Time<simulate> : 0.00233292579651 [s]
# Time: [0.0165|0.0024]
# Time<simulate> : 0.00296115875244 [s]
# Time: [0.0154|0.0030]
# Time<simulate> : 0.00190401077271 [s]
# Time: [0.0155|0.0023]
# Time<simulate> : 0.0020740032196 [s]
# Time: [0.0143|0.0021]
# Time<simulate> : 0.00162100791931 [s]
# Time: [0.0133|0.0017]
# Time<simulate> : 0.00160002708435 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.00174021720886 [s]
# Time: [0.0139|0.0018]
# Time<simulate> : 0.00161981582642 [s]
# Time: [0.0133|0.0017]
# Time<simulate> : 0.00161504745483 [s]
# Time: [0.0133|0.0016]
# Time<simulate> : 0.0018150806427 [s]
# Time: [0.0149|0.0019]
# Time<simulate> : 0.00157594680786 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.00155782699585 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00153517723083 [s]
# Time: [0.0135|0.0016]
# Time<simulate> : 0.00159192085266 [s]
# Time: [0.0125|0.0016]
# Time<simulate> : 0.00162410736084 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.00160098075867 [s]
# Time: [0.0129|0.0017]
# Time<simulate> : 0.00167798995972 [s]
# Time: [0.0144|0.0017]
# Time<simulate> : 0.0015230178833 [s]
# Time: [0.0130|0.0015]
# Time<simulate> : 0.00165104866028 [s]
# Time: [0.0130|0.0017]
# Time<simulate> : 0.00171184539795 [s]
# Time: [0.0136|0.0017]
# Time<simulate> : 0.00157308578491 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00168204307556 [s]
# Time: [0.0140|0.0017]
# Time<simulate> : 0.00185298919678 [s]
# Time: [0.0129|0.0019]
# Time<simulate> : 0.00209999084473 [s]
# Time: [0.0147|0.0022]
# Time<simulate> : 0.00187015533447 [s]
# Time: [0.0139|0.0019]
# Time<simulate> : 0.00187993049622 [s]
# Time: [0.0131|0.0019]
# Time<simulate> : 0.00156283378601 [s]
# Time: [0.0118|0.0016]
# Time<simulate> : 0.00162100791931 [s]
# Time: [0.0122|0.0016]
# Time<simulate> : 0.00249099731445 [s]
# Time: [0.0158|0.0026]
# Time<simulate> : 0.00159502029419 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00201892852783 [s]
# Time: [0.0150|0.0021]
# Time<simulate> : 0.00158786773682 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.00173592567444 [s]
# Time: [0.0145|0.0018]
# Time<simulate> : 0.00170087814331 [s]
# Time: [0.0141|0.0017]
# Time<simulate> : 0.00202202796936 [s]
# Time: [0.0149|0.0021]
# Time<simulate> : 0.00144505500793 [s]
# Time: [0.0130|0.0015]
# Time<simulate> : 0.00171804428101 [s]
# Time: [0.0145|0.0018]
# Time<simulate> : 0.00174903869629 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00156879425049 [s]
# Time: [0.0138|0.0016]
# Time<simulate> : 0.00178003311157 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00179409980774 [s]
# Time: [0.0148|0.0018]
# Time<simulate> : 0.00160098075867 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00169706344604 [s]
# Time: [0.0152|0.0017]
# Time<simulate> : 0.00152397155762 [s]
# Time: [0.0131|0.0015]
# Time<simulate> : 0.0016930103302 [s]
# Time: [0.0136|0.0017]
# Time<simulate> : 0.0019359588623 [s]
# Time: [0.0165|0.0020]
# Time<simulate> : 0.00178813934326 [s]
# Time: [0.0146|0.0018]
# Time<simulate> : 0.00158500671387 [s]
# Time: [0.0122|0.0016]
# Time<simulate> : 0.00198197364807 [s]
# Time: [0.0147|0.0020]
# Time<simulate> : 0.00155806541443 [s]
# Time: [0.0125|0.0016]
# Time<simulate> : 0.00173306465149 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00157403945923 [s]
# Time: [0.0127|0.0016]
# Time<simulate> : 0.00188589096069 [s]
# Time: [0.0148|0.0019]
# Time<simulate> : 0.00172996520996 [s]
# Time: [0.0151|0.0018]
# Time<simulate> : 0.00191497802734 [s]
# Time: [0.0156|0.0019]
# Time<simulate> : 0.00157117843628 [s]
# Time: [0.0123|0.0016]
# Time<simulate> : 0.00182604789734 [s]
# Time: [0.0148|0.0019]
# Time<simulate> : 0.00196099281311 [s]
# Time: [0.0140|0.0020]
# Time<simulate> : 0.00179004669189 [s]
# Time: [0.0148|0.0018]
# Time<simulate> : 0.002032995224 [s]
# Time: [0.0131|0.0021]
# Time<simulate> : 0.0017249584198 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00263094902039 [s]
# Time: [0.0179|0.0027]
# Time<simulate> : 0.00170683860779 [s]
# Time: [0.0146|0.0017]
# Time<simulate> : 0.0015721321106 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00196814537048 [s]
# Time: [0.0148|0.0020]
# Time<simulate> : 0.00186204910278 [s]
# Time: [0.0139|0.0019]
# Time<simulate> : 0.00157594680786 [s]
# Time: [0.0136|0.0016]
# Time<simulate> : 0.00148320198059 [s]
# Time: [0.0120|0.0015]
# Time<simulate> : 0.0019428730011 [s]
# Time: [0.0150|0.0020]
# Time<simulate> : 0.00286483764648 [s]
# Time: [0.0167|0.0029]
# Time<simulate> : 0.00185179710388 [s]
# Time: [0.0148|0.0019]
# Time<simulate> : 0.00167489051819 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.00195598602295 [s]
# Time: [0.0143|0.0020]
# Time<simulate> : 0.00194001197815 [s]
# Time: [0.0146|0.0020]
# Time<simulate> : 0.00197005271912 [s]
# Time: [0.0149|0.0020]
# Time<simulate> : 0.00162291526794 [s]
# Time: [0.0128|0.0016]
# Time<simulate> : 0.00169920921326 [s]
# Time: [0.0154|0.0017]
# Time<simulate> : 0.00173687934875 [s]
# Time: [0.0147|0.0018]
# Time<simulate> : 0.00196123123169 [s]
# Time: [0.0154|0.0020]
# Time<simulate> : 0.00162506103516 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00171709060669 [s]
# Time: [0.0141|0.0017]
# Time<simulate> : 0.00180315971375 [s]
# Time: [0.0144|0.0018]
# Time<simulate> : 0.00194001197815 [s]
# Time: [0.0145|0.0020]
# Time<simulate> : 0.00157403945923 [s]
# Time: [0.0123|0.0016]
# Time<simulate> : 0.00188612937927 [s]
# Time: [0.0147|0.0019]
# Time<simulate> : 0.0020010471344 [s]
# Time: [0.0160|0.0020]
# Time<simulate> : 0.00173187255859 [s]
# Time: [0.0147|0.0018]
# Time<simulate> : 0.00156879425049 [s]
# Time: [0.0123|0.0016]
# Time<simulate> : 0.00186204910278 [s]
# Time: [0.0156|0.0019]
# Time<simulate> : 0.00163793563843 [s]
# Time: [0.0135|0.0017]
# Time<simulate> : 0.00195598602295 [s]
# Time: [0.0152|0.0020]
# Time<simulate> : 0.00183296203613 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00167798995972 [s]
# Time: [0.0127|0.0017]
# Time<simulate> : 0.00160098075867 [s]
# Time: [0.0145|0.0016]
# Time<simulate> : 0.00189900398254 [s]
# Time: [0.0147|0.0019]
# Time<simulate> : 0.00205612182617 [s]
# Time: [0.0140|0.0021]
# Time<simulate> : 0.00161910057068 [s]
# Time: [0.0169|0.0017]
# Time<simulate> : 0.00180792808533 [s]
# Time: [0.0145|0.0023]
# Time<simulate> : 0.00163578987122 [s]
# Time: [0.0132|0.0017]
# Time<simulate> : 0.00162696838379 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00161600112915 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00157904624939 [s]
# Time: [0.0136|0.0020]
# Time<simulate> : 0.00158500671387 [s]
# Time: [0.0139|0.0016]
# Time<simulate> : 0.00165200233459 [s]
# Time: [0.0122|0.0017]
# Time<simulate> : 0.00153112411499 [s]
# Time: [0.0114|0.0016]
# Time<simulate> : 0.00161409378052 [s]
# Time: [0.0132|0.0020]
# Time<simulate> : 0.00185179710388 [s]
# Time: [0.0129|0.0019]
# Time<simulate> : 0.00158786773682 [s]
# Time: [0.0115|0.0016]
# Time<simulate> : 0.00154900550842 [s]
# Time: [0.0122|0.0016]
# Time<simulate> : 0.0014979839325 [s]
# Time: [0.0144|0.0015]
# Time<simulate> : 0.00198888778687 [s]
# Time: [0.0155|0.0020]
# Time<simulate> : 0.00154185295105 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00151109695435 [s]
# Time: [0.0139|0.0015]
# Time<simulate> : 0.00179815292358 [s]
# Time: [0.0153|0.0018]
# Time<simulate> : 0.00191307067871 [s]
# Time: [0.0148|0.0019]
# Time<simulate> : 0.00161695480347 [s]
# Time: [0.0131|0.0017]
# Time<simulate> : 0.00157189369202 [s]
# Time: [0.0122|0.0016]
# Time<simulate> : 0.00187397003174 [s]
# Time: [0.0132|0.0019]
# Time<simulate> : 0.00183582305908 [s]
# Time: [0.0139|0.0019]
# Time<simulate> : 0.00171399116516 [s]
# Time: [0.0140|0.0017]
# Time<simulate> : 0.00159621238708 [s]
# Time: [0.0137|0.0016]
# Time<simulate> : 0.00147914886475 [s]
# Time: [0.0130|0.0015]
# Time<simulate> : 0.00158905982971 [s]
# Time: [0.0148|0.0016]
# Time<simulate> : 0.00154399871826 [s]
# Time: [0.0123|0.0016]
# Time<simulate> : 0.00167894363403 [s]
# Time: [0.0147|0.0017]
# Time<simulate> : 0.00188803672791 [s]
# Time: [0.0143|0.0019]
# Time<simulate> : 0.00155210494995 [s]
# Time: [0.0133|0.0016]
# Time<simulate> : 0.00155401229858 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00165700912476 [s]
# Time: [0.0140|0.0017]
# Time<simulate> : 0.00219488143921 [s]
# Time: [0.0142|0.0022]
# Time<simulate> : 0.00166797637939 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.0015070438385 [s]
# Time: [0.0138|0.0015]
# Time<simulate> : 0.00161004066467 [s]
# Time: [0.0140|0.0016]
# Time<simulate> : 0.00181889533997 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00161695480347 [s]
# Time: [0.0138|0.0016]
# Time<simulate> : 0.00176787376404 [s]
# Time: [0.0139|0.0018]
# Time<simulate> : 0.00164318084717 [s]
# Time: [0.0129|0.0017]
# Time<simulate> : 0.00170302391052 [s]
# Time: [0.0147|0.0017]
# Time<simulate> : 0.00165510177612 [s]
# Time: [0.0131|0.0017]
# Time<simulate> : 0.00173401832581 [s]
# Time: [0.0146|0.0018]
# Time<simulate> : 0.00162506103516 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00168490409851 [s]
# Time: [0.0132|0.0017]
# Time<simulate> : 0.00173187255859 [s]
# Time: [0.0140|0.0018]
# Time<simulate> : 0.00158405303955 [s]
# Time: [0.0141|0.0016]
# Time<simulate> : 0.00153994560242 [s]
# Time: [0.0134|0.0016]
# Time<simulate> : 0.00170493125916 [s]
# Time: [0.0136|0.0017]
# Time<simulate> : 0.00188899040222 [s]
# Time: [0.0141|0.0019]
# Time<simulate> : 0.00173711776733 [s]
# Time: [0.0131|0.0018]
# Time<simulate> : 0.00156688690186 [s]
# Time: [0.0134|0.0016]
# Time<simulate> : 0.00208616256714 [s]
# Time: [0.0138|0.0021]
# Time<simulate> : 0.0015721321106 [s]
# Time: [0.0135|0.0016]
# Time<simulate> : 0.00161910057068 [s]
# Time: [0.0138|0.0017]
# Time<simulate> : 0.00160598754883 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.00208497047424 [s]
# Time: [0.0150|0.0021]
# Time<simulate> : 0.00180602073669 [s]
# Time: [0.0146|0.0018]
# Time<simulate> : 0.00164699554443 [s]
# Time: [0.0131|0.0017]
# Time<simulate> : 0.00161290168762 [s]
# Time: [0.0141|0.0016]
# Time<simulate> : 0.00182795524597 [s]
# Time: [0.0141|0.0019]
# Time<simulate> : 0.00169587135315 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.00189900398254 [s]
# Time: [0.0132|0.0019]
# Time<simulate> : 0.00160598754883 [s]
# Time: [0.0140|0.0016]
# Time<simulate> : 0.00159597396851 [s]
# Time: [0.0146|0.0016]
# Time<simulate> : 0.00187206268311 [s]
# Time: [0.0147|0.0019]
# Time<simulate> : 0.00149703025818 [s]
# Time: [0.0121|0.0015]
# Time<simulate> : 0.00150489807129 [s]
# Time: [0.0134|0.0015]
# Time<simulate> : 0.00184488296509 [s]
# Time: [0.0143|0.0019]
# Time<simulate> : 0.00168704986572 [s]
# Time: [0.0143|0.0017]
# Time<simulate> : 0.00157499313354 [s]
# Time: [0.0122|0.0016]
# Time<simulate> : 0.0015709400177 [s]
# Time: [0.0140|0.0016]
# Time<simulate> : 0.00156879425049 [s]
# Time: [0.0143|0.0016]
# Time<simulate> : 0.0016508102417 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.00167489051819 [s]
# Time: [0.0129|0.0017]
# Time<simulate> : 0.0014979839325 [s]
# Time: [0.0131|0.0015]
# Time<simulate> : 0.00188398361206 [s]
# Time: [0.0140|0.0019]
# Time<simulate> : 0.00156283378601 [s]
# Time: [0.0137|0.0016]
# Time<simulate> : 0.00163412094116 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.00167393684387 [s]
# Time: [0.0140|0.0017]
# Time<simulate> : 0.00182700157166 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00157284736633 [s]
# Time: [0.0144|0.0016]
# Time<simulate> : 0.00174188613892 [s]
# Time: [0.0128|0.0018]
# Time<simulate> : 0.00149202346802 [s]
# Time: [0.0127|0.0015]
# Time<simulate> : 0.0018367767334 [s]
# Time: [0.0140|0.0019]
# Time<simulate> : 0.00158405303955 [s]
# Time: [0.0152|0.0016]
# Time<simulate> : 0.00158309936523 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00152492523193 [s]
# Time: [0.0135|0.0016]
# Time<simulate> : 0.00180387496948 [s]
# Time: [0.0149|0.0018]
# Time<simulate> : 0.00177502632141 [s]
# Time: [0.0153|0.0018]
# Time<simulate> : 0.00155091285706 [s]
# Time: [0.0123|0.0016]
# Time<simulate> : 0.00157618522644 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.00177001953125 [s]
# Time: [0.0138|0.0018]
# Time<simulate> : 0.0018138885498 [s]
# Time: [0.0144|0.0019]
# Time<simulate> : 0.00172090530396 [s]
# Time: [0.0136|0.0018]
# Time<simulate> : 0.00157999992371 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.00160980224609 [s]
# Time: [0.0130|0.0016]
# Time<simulate> : 0.00154590606689 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00162506103516 [s]
# Time: [0.0123|0.0016]
# Time<simulate> : 0.00162196159363 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.00174307823181 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00169801712036 [s]
# Time: [0.0135|0.0017]
# Time<simulate> : 0.00156188011169 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.0016028881073 [s]
# Time: [0.0140|0.0016]
# Time<simulate> : 0.00203704833984 [s]
# Time: [0.0154|0.0021]
# Time<simulate> : 0.00178098678589 [s]
# Time: [0.0137|0.0018]
# Time<simulate> : 0.00166296958923 [s]
# Time: [0.0134|0.0017]
# Time<simulate> : 0.00169610977173 [s]
# Time: [0.0126|0.0017]
# Time<simulate> : 0.00152492523193 [s]
# Time: [0.0120|0.0015]
# Time<simulate> : 0.00178194046021 [s]
# Time: [0.0137|0.0018]
# Time<simulate> : 0.001797914505 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00162410736084 [s]
# Time: [0.0138|0.0017]
# Time<simulate> : 0.00163102149963 [s]
# Time: [0.0139|0.0017]
# Time<simulate> : 0.00188302993774 [s]
# Time: [0.0142|0.0019]
# Time<simulate> : 0.00164294242859 [s]
# Time: [0.0131|0.0017]
# Time<simulate> : 0.00172591209412 [s]
# Time: [0.0141|0.0018]
# Time<simulate> : 0.00157904624939 [s]
# Time: [0.0136|0.0016]
# Time<simulate> : 0.00157499313354 [s]
# Time: [0.0147|0.0016]
# Time<simulate> : 0.00153613090515 [s]
# Time: [0.0128|0.0016]
# Time<simulate> : 0.00156617164612 [s]
# Time: [0.0137|0.0016]
# Time<simulate> : 0.00161099433899 [s]
# Time: [0.0152|0.0016]
# Time<simulate> : 0.00165605545044 [s]
# Time: [0.0142|0.0017]
# Time<simulate> : 0.0016040802002 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.00155806541443 [s]
# Time: [0.0125|0.0016]
# Time<simulate> : 0.00175499916077 [s]
# Time: [0.0138|0.0018]
# Time<simulate> : 0.00160694122314 [s]
# Time: [0.0141|0.0016]
# Time<simulate> : 0.00155591964722 [s]
# Time: [0.0120|0.0016]
# Time<simulate> : 0.00165510177612 [s]
# Time: [0.0139|0.0017]
# Time<simulate> : 0.00178694725037 [s]
# Time: [0.0149|0.0018]
# Time<simulate> : 0.00182199478149 [s]
# Time: [0.0139|0.0018]
# Time<simulate> : 0.00172090530396 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00150609016418 [s]
# Time: [0.0128|0.0015]
# Time<simulate> : 0.00188302993774 [s]
# Time: [0.0143|0.0019]
# Time<simulate> : 0.00166893005371 [s]
# Time: [0.0138|0.0017]
# Time<simulate> : 0.00167202949524 [s]
# Time: [0.0129|0.0017]
# Time<simulate> : 0.00154614448547 [s]
# Time: [0.0130|0.0016]
# Time<simulate> : 0.00183987617493 [s]
# Time: [0.0154|0.0019]
# Time<simulate> : 0.00196409225464 [s]
# Time: [0.0148|0.0020]
# Time<simulate> : 0.00166511535645 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.00153684616089 [s]
# Time: [0.0126|0.0016]
# Time<simulate> : 0.00185394287109 [s]
# Time: [0.0136|0.0019]
# Time<simulate> : 0.00151801109314 [s]
# Time: [0.0137|0.0015]
# Time<simulate> : 0.0015709400177 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00166010856628 [s]
# Time: [0.0146|0.0017]
# Time<simulate> : 0.00192999839783 [s]
# Time: [0.0149|0.0020]
# Time<simulate> : 0.00208497047424 [s]
# Time: [0.0163|0.0021]
# Time<simulate> : 0.00154495239258 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00163102149963 [s]
# Time: [0.0129|0.0017]
# Time<simulate> : 0.00180292129517 [s]
# Time: [0.0141|0.0018]
# Time<simulate> : 0.00179386138916 [s]
# Time: [0.0140|0.0018]
# Time<simulate> : 0.00151515007019 [s]
# Time: [0.0128|0.0015]
# Time<simulate> : 0.00168299674988 [s]
# Time: [0.0134|0.0017]
# Time<simulate> : 0.0018150806427 [s]
# Time: [0.0137|0.0019]
# Time<simulate> : 0.00240898132324 [s]
# Time: [0.0163|0.0025]
# Time<simulate> : 0.0017261505127 [s]
# Time: [0.0150|0.0018]
# Time<simulate> : 0.00437903404236 [s]
# Time: [0.0180|0.0044]
# Time<simulate> : 0.00413084030151 [s]
# Time: [0.0209|0.0049]
# Time<simulate> : 0.00316214561462 [s]
# Time: [0.0166|0.0032]
# Time<simulate> : 0.00157022476196 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00236988067627 [s]
# Time: [0.0153|0.0024]
# Time<simulate> : 0.00159502029419 [s]
# Time: [0.0159|0.0016]
# Time<simulate> : 0.00270891189575 [s]
# Time: [0.0165|0.0028]
# Time<simulate> : 0.00163817405701 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.0032799243927 [s]
# Time: [0.0177|0.0038]
# Time<simulate> : 0.00310683250427 [s]
# Time: [0.0196|0.0031]
# Time<simulate> : 0.00198888778687 [s]
# Time: [0.0157|0.0020]
# Time<simulate> : 0.00238704681396 [s]
# Time: [0.0171|0.0029]
# Time<simulate> : 0.00316691398621 [s]
# Time: [0.0186|0.0032]
# Time<simulate> : 0.00184607505798 [s]
# Time: [0.0161|0.0019]
# Time<simulate> : 0.00354099273682 [s]
# Time: [0.0209|0.0041]
# Time<simulate> : 0.00252795219421 [s]
# Time: [0.0169|0.0026]
# Time<simulate> : 0.00160217285156 [s]
# Time: [0.0140|0.0016]
# Time<simulate> : 0.00181794166565 [s]
# Time: [0.0153|0.0019]
# Time<simulate> : 0.00192189216614 [s]
# Time: [0.0142|0.0020]
# Time<simulate> : 0.00165891647339 [s]
# Time: [0.0152|0.0017]
# Time<simulate> : 0.00161099433899 [s]
# Time: [0.0119|0.0016]
# Time<simulate> : 0.00329804420471 [s]
# Time: [0.0157|0.0034]
# Time<simulate> : 0.00158715248108 [s]
# Time: [0.0138|0.0016]
# Time<simulate> : 0.00243401527405 [s]
# Time: [0.0151|0.0025]
# Time<simulate> : 0.00162696838379 [s]
# Time: [0.0131|0.0017]
# Time<simulate> : 0.00349307060242 [s]
# Time: [0.0160|0.0036]
# Time<simulate> : 0.00183796882629 [s]
# Time: [0.0140|0.0019]
# Time<simulate> : 0.00154399871826 [s]
# Time: [0.0133|0.0016]
# Time<simulate> : 0.00193881988525 [s]
# Time: [0.0142|0.0020]
# Time<simulate> : 0.00325298309326 [s]
# Time: [0.0152|0.0033]
# Time<simulate> : 0.00164604187012 [s]
# Time: [0.0122|0.0017]
# Time<simulate> : 0.00156712532043 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.0019850730896 [s]
# Time: [0.0158|0.0020]
# Time<simulate> : 0.00161814689636 [s]
# Time: [0.0129|0.0016]
# Time<simulate> : 0.00188088417053 [s]
# Time: [0.0150|0.0019]
# Time<simulate> : 0.00184798240662 [s]
# Time: [0.0163|0.0019]
# Time<simulate> : 0.00167608261108 [s]
# Time: [0.0126|0.0017]
# Time<simulate> : 0.00163388252258 [s]
# Time: [0.0131|0.0017]
# Time<simulate> : 0.00157189369202 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.00177311897278 [s]
# Time: [0.0149|0.0018]
# Time<simulate> : 0.00153183937073 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00168108940125 [s]
# Time: [0.0140|0.0017]
# Time<simulate> : 0.00193214416504 [s]
# Time: [0.0139|0.0020]
# Time<simulate> : 0.00160002708435 [s]
# Time: [0.0128|0.0016]
# Time<simulate> : 0.00171995162964 [s]
# Time: [0.0134|0.0018]
# Time<simulate> : 0.00187087059021 [s]
# Time: [0.0144|0.0019]
# Time<simulate> : 0.00230002403259 [s]
# Time: [0.0161|0.0023]
# Time<simulate> : 0.00157904624939 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00173115730286 [s]
# Time: [0.0142|0.0018]
# Time<simulate> : 0.00163292884827 [s]
# Time: [0.0135|0.0017]
# Time<simulate> : 0.00189089775085 [s]
# Time: [0.0143|0.0019]
# Time<simulate> : 0.00168108940125 [s]
# Time: [0.0136|0.0017]
# Time<simulate> : 0.00168490409851 [s]
# Time: [0.0133|0.0017]
# Time<simulate> : 0.00160193443298 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.00163102149963 [s]
# Time: [0.0133|0.0017]
# Time<simulate> : 0.00169205665588 [s]
# Time: [0.0134|0.0017]
# Time<simulate> : 0.00152993202209 [s]
# Time: [0.0130|0.0015]
# Time<simulate> : 0.00187611579895 [s]
# Time: [0.0155|0.0019]
# Time<simulate> : 0.00160694122314 [s]
# Time: [0.0127|0.0016]
# Time<simulate> : 0.00164604187012 [s]
# Time: [0.0137|0.0017]
# Time<simulate> : 0.00149703025818 [s]
# Time: [0.0124|0.0015]
# Time<simulate> : 0.0028121471405 [s]
# Time: [0.0153|0.0028]
# Time<simulate> : 0.00162196159363 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00169587135315 [s]
# Time: [0.0134|0.0017]
# Time<simulate> : 0.00156116485596 [s]
# Time: [0.0128|0.0016]
# Time<simulate> : 0.00181102752686 [s]
# Time: [0.0137|0.0018]
# Time<simulate> : 0.00185990333557 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00168204307556 [s]
# Time: [0.0140|0.0017]
# Time<simulate> : 0.00188302993774 [s]
# Time: [0.0137|0.0019]
# Time<simulate> : 0.00173783302307 [s]
# Time: [0.0132|0.0018]
# Time<simulate> : 0.00160884857178 [s]
# Time: [0.0134|0.0016]
# Time<simulate> : 0.00167512893677 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.00154995918274 [s]
# Time: [0.0128|0.0016]
# Time<simulate> : 0.00172805786133 [s]
# Time: [0.0140|0.0018]
# Time<simulate> : 0.00180697441101 [s]
# Time: [0.0143|0.0018]
# Time<simulate> : 0.00191903114319 [s]
# Time: [0.0134|0.0020]
# Time<simulate> : 0.00152707099915 [s]
# Time: [0.0123|0.0015]
# Time<simulate> : 0.00157690048218 [s]
# Time: [0.0131|0.0016]
# Time<simulate> : 0.00195908546448 [s]
# Time: [0.0144|0.0020]
# Time<simulate> : 0.00171685218811 [s]
# Time: [0.0136|0.0018]
# Time<simulate> : 0.00151491165161 [s]
# Time: [0.0136|0.0015]
# Time<simulate> : 0.00154089927673 [s]
# Time: [0.0140|0.0016]
# Time<simulate> : 0.00160908699036 [s]
# Time: [0.0139|0.0016]
# Time<simulate> : 0.00176906585693 [s]
# Time: [0.0138|0.0018]
# Time<simulate> : 0.00160098075867 [s]
# Time: [0.0138|0.0016]
# Time<simulate> : 0.00175285339355 [s]
# Time: [0.0133|0.0018]
# Time<simulate> : 0.00218915939331 [s]
# Time: [0.0153|0.0022]
# Time<simulate> : 0.00211095809937 [s]
# Time: [0.0154|0.0021]
# Time<simulate> : 0.00169277191162 [s]
# Time: [0.0133|0.0017]
# Time<simulate> : 0.0015721321106 [s]
# Time: [0.0124|0.0016]
# Time<simulate> : 0.00157618522644 [s]
# Time: [0.0125|0.0016]
# Time<simulate> : 0.00165319442749 [s]
# Time: [0.0122|0.0017]
# Time<simulate> : 0.00170207023621 [s]
# Time: [0.0134|0.0017]
# Time<simulate> : 0.00183486938477 [s]
# Time: [0.0139|0.0019]
# Time<simulate> : 0.00203680992126 [s]
# Time: [0.0150|0.0021]
# Time<simulate> : 0.00166702270508 [s]
# Time: [0.0127|0.0017]
# Time<simulate> : 0.00151801109314 [s]
# Time: [0.0123|0.0015]
# Time<simulate> : 0.00188803672791 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00168514251709 [s]
# Time: [0.0140|0.0017]
# Time<simulate> : 0.00157499313354 [s]
# Time: [0.0125|0.0016]
# Time<simulate> : 0.00150299072266 [s]
# Time: [0.0132|0.0015]
# Time<simulate> : 0.00253915786743 [s]
# Time: [0.0167|0.0026]
# Time<simulate> : 0.00176906585693 [s]
# Time: [0.0144|0.0018]
# Time<simulate> : 0.00153398513794 [s]
# Time: [0.0127|0.0016]
# Time<simulate> : 0.00151205062866 [s]
# Time: [0.0126|0.0015]
# Time<simulate> : 0.00175094604492 [s]
# Time: [0.0140|0.0018]
# Time<simulate> : 0.00189805030823 [s]
# Time: [0.0150|0.0019]
# Time<simulate> : 0.00166487693787 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.00162982940674 [s]
# Time: [0.0128|0.0017]
# Time<simulate> : 0.00188612937927 [s]
# Time: [0.0146|0.0019]
# Time<simulate> : 0.00151705741882 [s]
# Time: [0.0130|0.0015]
# Time<simulate> : 0.00171995162964 [s]
# Time: [0.0131|0.0018]
# Time<simulate> : 0.00161004066467 [s]
# Time: [0.0138|0.0016]
# Time<simulate> : 0.00159192085266 [s]
# Time: [0.0142|0.0016]
# Time<simulate> : 0.0018048286438 [s]
# Time: [0.0138|0.0018]
# Time<simulate> : 0.00154900550842 [s]
# Time: [0.0132|0.0016]
# Time<simulate> : 0.00155401229858 [s]
# Time: [0.0117|0.0016]
# Total time: 8.82957100868

# %%
# Load the HDF5 files and plot them
from multiscale.simulate import solve_io
reload(solve_io)
plt.figure(figsize=(10, 7))
for sim in simulations_double:
    result = Result.objects.get(simulation=sim, result_type=db_api.ResultType.HDF5)
    data, header = solve_io.load_hdf5(result.filepath)
    plt.plot(data[:,0], data[:,1:], '-', color='grey')
    
for sim in simulations:
    result = Result.objects.get(simulation=sim, result_type=db_api.ResultType.HDF5)
    data, header = solve_io.load_hdf5(result.filepath)
    plt.plot(data[:,0], data[:,1:], '-', color='black')
    
plt.xlabel('time [s]', fontsize=plt_fontsize)
plt.ylabel('species [mM]', fontsize=plt_fontsize)
