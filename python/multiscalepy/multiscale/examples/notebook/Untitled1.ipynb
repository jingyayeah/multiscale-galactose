# %%
import multiscale.odesim.simulate.roadrunner_tools as rt
import multiscale.examples.testdata as testdata
reload(rt)
r = rt.MyRunner(testdata.demo_sbml)
r.simulate(0,10,101)
# Out:
# Time<__init__> SBML compile: 0.0245649814606 [s]
# Time<simulate> : 0.00115489959717 [s]
#            time,  [e__A],      [e__C],      [e__B],      [c__C],      [c__B],      [c__A]
#  [[           0,      10,           0,           0,           0,           0,           0],
#   [ 1.10255e-10,      10, 2.03071e-30, 2.43685e-29, 2.76275e-20,  5.5255e-20, 5.01158e-10],
#   [ 1.10266e-06, 9.99999,  2.0309e-18, 2.43706e-17, 2.76301e-12, 5.52601e-12, 5.01206e-06],
#   [ 1.21281e-05, 9.99994, 1.06024e-15, 1.27223e-14, 2.14571e-10, 4.29132e-10, 5.51268e-05],
#   [ 4.04514e-05, 9.99982,  2.6546e-14, 3.18514e-13, 2.00802e-09,  4.0158e-09,  0.00018386],
#   [ 9.71494e-05, 9.99956, 3.12611e-13, 3.75039e-12, 1.10074e-08,  2.2012e-08, 0.000441535],
#   [ 0.000200705, 9.99909, 2.54743e-12, 3.05546e-11, 4.61964e-08, 9.23704e-08, 0.000912073],
#   [ 0.000384026, 9.99825,  1.7126e-11, 2.05335e-10, 1.68086e-07, 3.36021e-07,  0.00174476],
#   [ 0.000708065, 9.99678, 1.05082e-10, 1.25903e-09, 5.69914e-07,  1.1389e-06,  0.00321573],
#   [  0.00131332, 9.99403, 6.67213e-10, 7.98373e-09, 1.95737e-06, 3.90889e-06,  0.00596019],
#   [  0.00233919, 9.98938, 3.72027e-09, 4.44215e-08, 6.19912e-06, 1.23657e-05,   0.0106028],
#   [  0.00336506, 9.98473, 1.05747e-08, 1.26066e-07, 1.28122e-05, 2.55322e-05,   0.0152339],
#   [  0.00439094, 9.98008, 2.27833e-08, 2.71198e-07, 2.17882e-05, 4.33784e-05,   0.0198537],
#   [  0.00541681, 9.97544, 4.19338e-08, 4.98396e-07, 3.31187e-05, 6.58738e-05,    0.024462],
#   [  0.00666401,  9.9698, 7.66339e-08, 9.09188e-07, 5.00538e-05, 9.94447e-05,   0.0300492],
#   [  0.00791121, 9.96417, 1.26553e-07, 1.49873e-06,  7.0442e-05, 0.000139792,   0.0356197],
#   [  0.00915841, 9.95854, 1.94674e-07, 2.30123e-06, 9.42672e-05,  0.00018686,   0.0411735],
#   [   0.0111108, 9.94975, 3.44787e-07, 4.06354e-06, 0.000138428, 0.000273904,   0.0498342],
#   [   0.0130633, 9.94097, 5.57559e-07, 6.55121e-06, 0.000190913, 0.000377075,   0.0584544],
#   [   0.0150157, 9.93221, 8.43727e-07, 9.88327e-06, 0.000251664, 0.000496171,   0.0670341],
#   [   0.0169681, 9.92346, 1.21389e-06, 1.41755e-05, 0.000320622, 0.000630995,   0.0755737],
#   [   0.0199626, 9.91007, 1.96883e-06, 2.28812e-05,   0.0004422, 0.000867899,   0.0885935],
#   [   0.0229571, 9.89672, 2.98356e-06, 3.45069e-05, 0.000582741,  0.00114066,     0.10152],
#   [   0.0259516,  9.8834, 4.29518e-06, 4.94363e-05, 0.000742037,  0.00144861,    0.114354],
#   [     1.20075, 6.13298,    0.127427,    0.461929,     0.49695,      1.0188,     1.76192],
#   [     1.23426, 6.05113,    0.134309,    0.480803,    0.511421,     1.05532,     1.76701],
#   [     1.26776, 5.97021,    0.141287,     0.49974,    0.525698,     1.09176,     1.77131],
#   [     1.30126,  5.8902,    0.148355,    0.518734,     0.53978,     1.12808,     1.77485],
#   [     1.33477, 5.81108,    0.155508,    0.537776,    0.553667,     1.16427,     1.77769],
#   [     1.36827, 5.73286,    0.162739,     0.55686,    0.567357,     1.20031,     1.77988],
#   [     1.40177,  5.6555,    0.170043,    0.575977,    0.580852,     1.23619,     1.78144],
#   [     1.43528, 5.57901,    0.177415,    0.595123,    0.594152,     1.27188,     1.78242],
#   [     1.46878, 5.50337,    0.184849,    0.614292,    0.607256,     1.30738,     1.78285],
#   [     1.50228, 5.42858,    0.192341,    0.633477,    0.620166,     1.34267,     1.78277],
#   [     1.53579, 5.35462,    0.199886,    0.652673,    0.632883,     1.37774,      1.7822]]

# %%
# cast to super class for untimed behavior
# Out:
# Time<__init__> Model loading: 0.0302379131317 [s]

# %%
def simulate_complex(initial_concentrations={}, initial_amounts={},
                         parameters={}, reset_parameters=False, **kwargs):
    print(kwargs)
    
simulate_complex(start=0, end=20, initial_amounts="amounts")
# Out:
# {'start': 0, 'end': 20}

# %%
r
# Out:
# <roadrunner.RoadRunner() { this = 0x2e97170 }>

# %%
print(r.model.getFloatingSpeciesIds())
# Out:
# ['e__A', 'e__C', 'e__B', 'c__C', 'c__B', 'c__A']

# %%
from multiscale.examples.testdata import demo_sbml
reload(rt)
r = rt.MyRunner(demo_sbml)
r['init(e__A)'] = 1.0
r['init(e__B)'] = 1.0
r['init(c__C)'] = 1.0
# Out:
# Time<__init__> SBML compile: 0.0245649814606 [s]

# %%
import roadrunner
print(roadrunner.__version__)
from multiscale.examples.testdata import demo_sbml
# demo_sbml = "https://raw.githubusercontent.com/matthiaskoenig/multiscale-galactose/develop/python/multiscalepy/multiscale/examples/models/demo/Koenig_demo_10.xml"

def _set_values(r, value_dict):
    """
    Set values in model from {selection: value}.
    :return: {selection: original} returns dictionary of original values.
    """
    changed = dict()
    for key, value in value_dict.items():
        changed[key] = r[key]
        r[key] = value
    return changed

r = roadrunner.RoadRunner(demo_sbml)

# set initial concentrations (working)
d1 = {'init([e__A])': 1.0, 'init([e__B])': 14.3, 'init([c__C])': -3.0}
_set_values(r, d1)
for key in d1:
    print(d1[key], r[key])

print('*'*80)

# set initial amounts(not working ?)
d2 = {'init(e__A)': 1, 'init(e__B)': 15, 'init(c__C)': -20}
_set_values(r, d2)
for key in d2:
    print(d2[key], r[key])
    
print('*'*80)
    
# access no problem and values set:
print(r['e__A'])
print(r['e__B'])
print(r['c__C'])
# Out:
# 1.4.2; Compiler: gcc 4.8.4, C++ version: 199711; JIT Compiler: LLVM-3.4; Date: Jan 20 2016, 08:49:40
# (14.3, 14.3)
# (1.0, 1.0)
# (-3.0, -3.0)
# ********************************************************************************
# (1, 0.0)
# (15, 0.0)
# (-20, 0.0)
# ********************************************************************************
# 1.0
# 15.0
# -20.0
