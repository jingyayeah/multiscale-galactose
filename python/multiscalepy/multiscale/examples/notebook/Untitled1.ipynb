# %%
import multiscale.odesim.simulate.roadrunner_tools as rt
import multiscale.examples.testdata as testdata
reload(rt)
r = rt.MyRunner(testdata.demo_sbml)
r.simulate(0,10,101)
# Out:
# Time<__init__> SBML compile: 0.0476980209351 [s]
# Time<simulate> : 0.000898838043213 [s]
#     time,   [e__A],      [e__C],     [e__B],    [c__C],    [c__B],   [c__A]
#  [[    0,       10,           0,          0,         0,         0,        0],
#   [  0.1,  9.56455, 0.000239924, 0.00238415, 0.0100256,  0.018483, 0.404317],
#   [  0.2,  9.16242,  0.00163528,  0.0139888, 0.0358967, 0.0635474, 0.722523],
#   [  0.3,  8.78742,  0.00492229,  0.0363019, 0.0722591,  0.125928, 0.973179],
#   [  0.4,  8.43492,   0.0104543,  0.0674432,  0.115256,  0.201347,  1.17058],
#   [  0.5,  8.10148,   0.0183292,   0.105371,  0.162207,  0.286988,  1.32562],
#   [  0.6,  7.78439,   0.0284973,   0.148422,   0.21119,  0.380545,  1.44695],
#   [  0.7,  7.48156,   0.0408138,   0.195319,  0.260862,  0.480077,  1.54136],
#   [  0.8,  7.19132,   0.0550827,   0.245108,  0.310302,  0.583918,  1.61424],
#   [  0.9,  6.91242,   0.0710809,   0.297098,  0.358916,  0.690681,  1.66978],
# ...

# %%
# cast to super class for untimed behavior
# Out:
# Time<__init__> Model loading: 0.0302379131317 [s]

# %%
def simulate_c(parameters={}, initial_concentrations={}, initial_amounts={}, *args, **kwargs):
    print(args)
    print(kwargs)
    
simulate_c(args, kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-bdc683d1d02f> in <module>()
#       3     print(kwargs)
#       4
# ----> 5 simulate_c(args, kwargs)
#
# NameError: name 'args' is not defined
