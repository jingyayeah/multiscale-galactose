# %% [markdown]
# # Tellurium
# Some tests with tellurium

# %%
# http://tellurium.analogmachine.org/testing/
import tellurium as te
r = te.loada ('''
model feedback()
   // Reactions:
   J0: $X0 -> S1; (VM1 * (X0 - S1/Keq1))/(1 + X0 + S1 +   S4^h);
   J1: S1 -> S2; (10 * S1 - 2 * S2) / (1 + S1 + S2);
   J2: S2 -> S3; (10 * S2 - 2 * S3) / (1 + S2 + S3);
   J3: S3 -> S4; (10 * S3 - 2 * S4) / (1 + S3 + S4);
   J4: S4 -> $X1; (V4 * S4) / (KS4 + S4);

  // Species initializations:
  S1 = 0; S2 = 0; S3 = 0;
  S4 = 0; X0 = 10; X1 = 0;

  // Variable initialization:
  VM1 = 10; Keq1 = 10; h = 10; V4 = 2.5; KS4 = 0.5;
end''')

res = r.simulate(0, 40, 500)
r.plot()

import roadrunner
roadrunner.testing.tester.runTester()
# Out:
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Two_Cycles.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 2.26189339422e-07
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 3.61462428791e-15
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Test_1.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 1.38777878078e-17
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Check [Get Species Initial Concentrations By Index]PASS
# Check [Get Initial Floating Species Concs]   PASS
# Check [Set Species Initial Concentrations By Index]PASS
# Check [Set Species Initial Concentrations]   PASS
# Computing Steady State.  Distance to SteadyState: 3.92523114671e-17
# Check [Steady State Fluxes]                  PASS
# Check [Full Jacobian]                        PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
# Check [Floating Species Ids]                 PASS
# Check [Boundary Species Ids]                 PASS
# Check [Global Parameter Ids]                 PASS
# Check [Compartment Ids]                      PASS
# Check [Reaction Ids]                         PASS
# Check [Species Initial Concentration Ids]    PASS
# Check [Get Eigenvalue Ids]                   PASS
# [Get Rates Of Change Ids]                     UNKNOWN TEST
# Check [Set Steady State Selection List 2]    PASS
# Computing Steady State.  Distance to SteadyState: 1.38777878078e-17
# Check [Get Steady State Selection List 2]    PASS
# Check [Set Time Course Selection List]       PASS
# Check [Get Time Course Selection List]       PASS
# Check [Compute Steady State Values]          PASS
# Check [Floating Species Concentrations]      PASS
# Check [Boundary Species Concentrations]      PASS
# Check [Get Global Parameter Values]          PASS
# Check [Get Reaction Rates]                   PASS
# Check [Get Reaction Rates By Index]          PASS
# Check [Number of Dependent Species]          PASS
# Check [Number of Independent Species]        PASS
# Check [Number Of Rate Rules]                 PASS
# Check [Get Rates Of Change]                  PASS
# [Get Reaction Rates Ex]                       UNKNOWN TEST
# [Get Rates of Change Ex]                      UNKNOWN TEST
# [Get Rates of Change By Index]                UNKNOWN TEST
# Check [Get Control Coefficient]              PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/oscli.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 2.44931911407e-10
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 0.0
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/reversible_Jacobian.rrtest
# Successfully loaded model.
#
# Computing Steady State.  Distance to SteadyState: 5.63376654499e-16
# Check [Steady State Fluxes]                  PASS
# Check [Get Steady State Selection List]      PASS
# Check [Reduced Jacobian]                     PASS
# Check [Full Jacobian]                        PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Three_Steps.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 3.98278216043e-08
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 2.22044604925e-16
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Simple_Branch.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 2.18047246925e-11
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 1.66533453694e-16
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/MultiBranch2.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 1.65020398029e-07
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 3.42933771695e-15
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Cycle.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 4.09844528248e-09
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 1.14439169963e-15
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Two_Steps.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 5.08075683928e-07
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 8.9681734261e-14
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Futile_Cycle.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 3.25085354192e-11
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 8.00593208497e-16
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Cycle_to_Input_and_Branch.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 4.46816770095e-10
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 1.99707204133e-14
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Multibranch1.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 4.11202430133e-09
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 9.93013661299e-16
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Bimolecular_end.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 7.99276619683e-06
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 1.00004290316e-13
# Check [Steady State Fluxes]                  PASS
# Check [Full Jacobian]                        PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
# Check [Get Reaction Rates]                   PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Conserved_Cycle.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 4.49685355619e-09
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 4.4408920985e-16
# Check [Steady State Fluxes]                  PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
# Check [Get Reaction Rates]                   PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Test_2.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 8.32667268469e-17
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Check [Get Species Initial Concentrations By Index]PASS
# Check [Set Species Initial Concentrations By Index]PASS
# Check [Set Species Initial Concentrations]   PASS
# Computing Steady State.  Distance to SteadyState: 1.44222201479e-16
# Check [Steady State Fluxes]                  PASS
# Check [Full Jacobian]                        PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Boundary Species Concentrations]      PASS
# Check [Get Global Parameter Values]          PASS
# Check [Get Reaction Rates]                   PASS
# Check [Get Reaction Rates By Index]          PASS
# Check [Number of Dependent Species]          PASS
# Check [Number of Independent Species]        PASS
# Check [Number Of Rate Rules]                 PASS
# Check [Get Rates Of Change]                  PASS
# [Get Reaction Rates Ex]                       UNKNOWN TEST
# [Get Rates of Change Ex]                      UNKNOWN TEST
# Check [Amount/Concentration Jacobians]       PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Comp.rrtest
# Successfully loaded model.
#
# Check [Floating Species Ids]                 PASS
# Check [Boundary Species Ids]                 PASS
# Check [Global Parameter Ids]                 PASS
# Check [Compartment Ids]                      PASS
# Check [Reaction Ids]                         PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Conserved_Cycle_and_Branch.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 1.31227974026e-09
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 2.45293852586e-14
# Check [Steady State Fluxes]                  PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Get Reaction Rates]                   PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Cycle_across_branches.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 2.09538827608e-06
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 7.8240402763e-14
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Reduced Stoichiometry Matrix]         PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/variable_time_step.rrtest
# Successfully loaded model.
#
# Check [Get Variable End Time]                PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Four_Steps.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 7.37689124929e-06
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Computing Steady State.  Distance to SteadyState: 3.5412279041e-11
# Check [Steady State Fluxes]                  PASS
# Check [Get Reaction Rates]                   PASS
# Check [Full Jacobian]                        PASS
# Check [Reduced Jacobian]                     PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Reduced Eigenvalue Matrix]            PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/jacobian_1.rrtest
# Successfully loaded model.
#
# Check [Amount/Concentration Jacobians]       PASS
# Check [Full Jacobian]                        PASS
# Check [Amount Jacobian]                      PASS
# Computing Steady State.  Distance to SteadyState: 4.80740671596e-17
# Check [Steady State Fluxes]                  PASS
# Check [Species Concentrations]               PASS
# Check [Get Steady State Selection List]      PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Individual Amount Eigenvalues]        PASS
# Check [Eigenvalue Amount Matrix]             PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Elasticity Amount Matrix]    PASS
# Check [Scaled Elasticity Amount Matrix]      PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Scaled Flux Control Matrix]           PASS
# Check [Get Control Coefficient]              PASS
#
#
# Starting Test on  /usr/local/lib/python2.7/dist-packages/roadrunner/testing/test_data/Test_3.rrtest
# Successfully loaded model.
#
# Check [Set Steady State Selection List]      PASS
# Computing Steady State.  Distance to SteadyState: 1.86190061494e-16
# Check [Get Steady State Selection List]      PASS
# Check [Species Concentrations]               PASS
# Check [Set Species Initial Concentrations]   PASS
# Computing Steady State.  Distance to SteadyState: 1.86190061494e-16
# Check [Steady State Fluxes]                  PASS
# Check [Full Jacobian]                        PASS
# Check [Individual Eigenvalues]               PASS
# Check [Eigenvalue Matrix]                    PASS
# Check [Stoichiometry Matrix]                 PASS
# Check [Link Matrix]                          PASS
# Check [Unscaled Elasticity Matrix]           PASS
# Check [Scaled Elasticity Matrix]             PASS
# Check [Unscaled Concentration Control Matrix]PASS
# Check [Scaled Concentration Control Matrix]  PASS
# Check [Unscaled Flux Control Matrix]         PASS
# Check [Scaled Flux Control Matrix]           PASS
# Check [Get Reaction Rates]                   PASS
# Check [Get Reaction Rates By Index]          PASS
# Check [Get Rates Of Change]                  PASS
# Check [Get Control Coefficient]              PASS
#
#
# Total failed tests:	 0
# Total unknown tests:	 6
# Total passed tests:	 384
# 0

# %% [markdown]
# ## Bistable
# Example showing how to to multiple time course simulations, merging the data and plotting it onto one platting surface. Alternative is to use setHold()
#
# Model is a bistable system, simulations start with different initial conditions resulting in different steady states reached.

# %%
import tellurium as te
import numpy as np

r = te.loada ('''
$Xo -> S1; 1 + Xo*(32+(S1/0.75)^3.2)/(1 +(S1/4.3)^3.2);
S1 -> $X1; k1*S1;

Xo = 0.09; X1 = 0.0;
S1 = 0.5; k1 = 3.2;
''')

??np.hstack

print(r.selections)

initValue = 0.05
m = np.linspace(0,4,101)
print(m)

for i in range (0,12):
    r.model.S1 = initValue
    res = r.simulate (0, 4, 100)
    data = res['[S1]']
    print(data.size)
    m = np.concatenate([m, data], axis=1)
    initValue += 1

te.plotArray (m)
# Out:
# ['time', '[S1]']
# [ 0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36  0.4   0.44
#   0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84  0.88  0.92
#   0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32  1.36  1.4
#   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8   1.84  1.88
#   1.92  1.96  2.    2.04  2.08  2.12  2.16  2.2   2.24  2.28  2.32  2.36
#   2.4   2.44  2.48  2.52  2.56  2.6   2.64  2.68  2.72  2.76  2.8   2.84
#   2.88  2.92  2.96  3.    3.04  3.08  3.12  3.16  3.2   3.24  3.28  3.32
#   3.36  3.4   3.44  3.48  3.52  3.56  3.6   3.64  3.68  3.72  3.76  3.8
#   3.84  3.88  3.92  3.96  4.  ]
# 100
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-f7a9c98df178> in <module>()
#      23     data = res['[S1]']
#      24     print(data.size)
# ---> 25     m = np.concatenate([m, data], axis=1)
#      26     initValue += 1
#      27
#
# IndexError: axis 1 out of bounds [0, 1)

# %%
import tellurium as te
import numpy
import matplotlib.pyplot as plt
import roadrunner

# Example showing how to embelise a graph, change title, axes labels.
# Example also uses an event to pulse S1

r = te.loada ('''
   $Xo -> S1; k1*Xo;
   S1 -> $X1; k2*S1;
   
   k1 = 0.2; k2 = 0.4; Xo = 1; S1 = 0.5;
   at (time > 20): S1 = S1 + 0.35
''')

# Simulate the first part up to 20 time units
m = r.simulate (0, 50, 100, ["time", "S1"]);

plt.ylim ((0,1))
plt.xlabel ('Time')
plt.ylabel ('Concentration')
plt.title ('My First Plot ($y = x^2$)')
r.plot (m)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>

# %%
import tellurium as te
import matplotlib.pyplot as plt

# Example showing use of events and how to set the y axis limits
r = te.loada ('''
  $Xo -> S;   Xo/(km + S^h);
  S -> $w;  k1*S;       

     # initialize
     h = 1;   # Hill coefficient
     k1 = 1;  km = 0.1;
     S = 1.5; Xo = 2
     
     at (time > 10): Xo = 5;
     at (time > 20): Xo = 2;
''')

m1 = r.simulate (0, 30, 200, ['time', 'Xo', 'S'])

plt.ylim ((0,10))
r.plot (m1)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>

# %%
import tellurium as te
import numpy

# Model desribes a cascade of two genes. First gene is activated
# second gene is repressed. Uses events to change the input 
# to the gene regulatory network

r = te.loada ('''
    v1:  -> P1; Vm1*I^4/(Km1 + I^4);
    v2:  P1 -> ; k1*P1;
    v3:  -> P2;  Vm2/(Km2 + P1^4);
    v4:  P2 -> ; k2*P2;
    
    at (time > 60): I = 10;
    at (time > 100): I = 0.01;
    Vm1  = 5; Vm2 = 6; Km1 = 0.5; Km2 = 0.4;
    k1 = 0.1; k2 = 0.1;
    I = 0.01;
''')

result = r.simulate (0, 200, 100)
r.plot (result)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>

# %%
import tellurium as te

# Example of using antimony to create a stoichiometry matrix 
r = te.loada ('''
 -> S1; v1;
 S1 -> S2; v2;
 S2 -> ; v3;
 S3 -> S1; v4;
 S3 -> S2; v5;
 -> S3; v6;
''')

print r.getFullStoichiometryMatrix()
# Out:
# ERROR: An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-28-f32551f9c487> in <module>()
#       9  S3 -> S2; v5;
#      10  -> S3; v6;
# ---> 11 ''')
#      12
#      13 print r.getFullStoichiometryMatrix()
#
# /usr/local/lib/python2.7/dist-packages/tellurium/tellurium.pyc in loada(antStr)
#     200 #\return Returns a reference to the roadrunner model
#     201 def loada (antStr):
# --> 202     return loadAntimonyModel (antStr)
#     203
#     204 ##\brief Reads a CellML string into roadrunner
#
# /usr/local/lib/python2.7/dist-packages/tellurium/tellurium.pyc in loadAntimonyModel(antStr)
#     183
#     184     if (err < 0):
# --> 185        raise Exception('Antimony: ' + antimony.getLastError())
#     186
#     187     Id = antimony.getMainModuleName()
#
# Exception: Antimony: Error in model string, line 2:  syntax error, unexpected '>', expecting number

# %% [markdown]
# ## Lorent attractor
# Example showing how to describe a model using ODES. Example implements the Lorenz attractor.

# %%
import tellurium as te

r = te.loada ('''
     x' = sigma*(y - x);
     y' = x*(rho - z) - y;
     z' = x*y - beta*z;

     x = 0.96259;  y = 2.07272;  z = 18.65888;

     sigma = 10;  rho = 28; beta = 2.67;
''')

result = r.simulate (0, 20, 1000, ['time', 'x', 'y', 'z'])
r.plot (result)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>

# %%
# Time Course Parameter Scan
# Do 5 simulations on a simple model, for each simulation
# a parameter, k1 is changed. The script merges the data together
# and plots the merged array on to one plot. The alternative is
# is to use the setHold method and to plot each graph individually.

import tellurium as te
import numpy

r = te.loada ('''
    J1: $X0 -> S1; k1*X0;
    J2: S1 -> $X1; k2*S1;

    X0 = 1.0; S1 = 0.0; X1 = 0.0;
    k1 = 0.4; k2 = 2.3;
''')  
  
  
m = r.simulate (0, 4, 100, ["Time", "S1"])
for i in range (0,4):
    r.model.k1 = r.model.k1 + 0.1 
    r.reset()
    m = numpy.hstack ((m, r.simulate (0, 4, 100, ['S1'])))

# MUST use plotArray to plot merged data
te.plotArray (m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-6d9dc0ab35cb> in <module>()
#      19 m = r.simulate (0, 4, 100, ["Time", "S1"])
#      20 for i in range (0,4):
# ---> 21     r.model.k1 = r.model.k1 + 0.1
#      22     r.reset()
#      23     m = numpy.hstack ((m, r.simulate (0, 4, 100, ['S1'])))
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in <lambda>(self, name)
#    1145     __setattr__ = lambda self, name, value: _swig_setattr(self, ExecutableModel, name, value)
#    1146     __swig_getmethods__ = {}
# -> 1147     __getattr__ = lambda self, name: _swig_getattr(self, ExecutableModel, name)
#    1148     def __init__(self, *args, **kwargs): raise AttributeError("No constructor defined - class is abstract")
#    1149     def getExecutableModelDesc(self): return _roadrunner.ExecutableModel_getExecutableModelDesc(self)
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in _swig_getattr(self, class_type, name)
#      59     method = class_type.__swig_getmethods__.get(name,None)
#      60     if method: return method(self)
# ---> 61     raise AttributeError(name)
#      62
#      63 def _swig_repr(self):
#
# AttributeError: k1

# %%
import tellurium as te
import numpy

# Example of merging multiple simulations. In between simulations
# a parameter is changed.

r = te.loada ('''
    # Model Definition
    v1: $Xo -> S1;  k1*Xo;
    v2: S1 -> $w;   k2*S1;

    # Initialize constants 
    k1 = 1; k2 = 1; S1 = 15; Xo = 1;
''')

# Time course simulation
m1 = r.simulate (0, 15, 100, ["Time","S1"]);
r.model.k1 = r.model.k1 * 6;
m2 = r.simulate (15, 40, 100, ["Time","S1"]);
r.model.k1 = r.model.k1 / 6;
m3 = r.simulate (40, 60, 100, ["Time","S1"]);

m = numpy.vstack ((m1, m2, m3)); # Merge data
r.plot (m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-a2157d0f2970> in <module>()
#      16 # Time course simulation
#      17 m1 = r.simulate (0, 15, 100, ["Time","S1"]);
# ---> 18 r.model.k1 = r.model.k1 * 6;
#      19 m2 = r.simulate (15, 40, 100, ["Time","S1"]);
#      20 r.model.k1 = r.model.k1 / 6;
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in <lambda>(self, name)
#    1145     __setattr__ = lambda self, name, value: _swig_setattr(self, ExecutableModel, name, value)
#    1146     __swig_getmethods__ = {}
# -> 1147     __getattr__ = lambda self, name: _swig_getattr(self, ExecutableModel, name)
#    1148     def __init__(self, *args, **kwargs): raise AttributeError("No constructor defined - class is abstract")
#    1149     def getExecutableModelDesc(self): return _roadrunner.ExecutableModel_getExecutableModelDesc(self)
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in _swig_getattr(self, class_type, name)
#      59     method = class_type.__swig_getmethods__.get(name,None)
#      60     if method: return method(self)
# ---> 61     raise AttributeError(name)
#      62
#      63 def _swig_repr(self):
#
# AttributeError: k1

# %% [markdown]
# ## Relaxation oscillator
# Oscillator that uses positive and negative feedback.
# An example of a relaxation oscillator.

# %%
import tellurium as te

r = te.loada ('''
  v1: $Xo -> S1; k1*Xo;
  v2:  S1 -> S2; k2*S1*S2^h/(10 + S2^h) + k3*S1;
  v3:  S2 -> $w; k4*S2;      

  # Initialize
  h  = 2; # Hill coefficient
  k1 = 1; k2 = 2; Xo = 1;
  k3 = 0.02; k4 = 1;
''')

result = r.simulate (0, 100, 100)
r.plot (result)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>

# %%
import tellurium as te
import numpy

# Negative Feedback model where we scan over the value
# of the Hill coefficient.

r = te.loada ('''
  // Reactions:
  J0: $X0 => S1; (J0_VM1*(X0 - S1/J0_Keq1))/(1 + X0 + S1 + S4^J0_h);
  J1: S1 => S2; (10*S1 - 2*S2)/(1 + S1 + S2);
  J2: S2 => S3; (10*S2 - 2*S3)/(1 + S2 + S3);
  J3: S3 => S4; (10*S3 - 2*S4)/(1 + S3 + S4);
  J4: S4 => $X1; (J4_V4*S4)/(J4_KS4 + S4);

  // Species initializations:
  S1 = 0;
  S2 = 0;
  S3 = 0;
  S4 = 0;
  X0 = 10;
  X1 = 0;

  // Variable initializations:
  J0_VM1 = 10;
  J0_Keq1 = 10;
  J0_h = 2;
  J4_V4 = 2.5;
  J4_KS4 = 0.5;

  // Other declarations:
  const compartment_, J0_VM1, J0_Keq1, J0_h, J4_V4, J4_KS4;
''')

result = r.simulate (0, 20,200, ['time', 'S1'], reset=True)
for i in range (0,8):
    m = r.simulate (0, 20, 200, ['S1'], reset = True)
    result = numpy.hstack ((result, m))
    r.model.J0_h = r.model.J0_h + 1
    
te.plotArray(result)
# Out:
# ERROR: An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-b469172fa10c> in <module>()
#      30   // Other declarations:
#      31   const compartment_, J0_VM1, J0_Keq1, J0_h, J4_V4, J4_KS4;
# ---> 32 ''')
#      33
#      34 result = r.simulate (0, 20,200, ['time', 'S1'], reset=True)
#
# /usr/local/lib/python2.7/dist-packages/tellurium/tellurium.pyc in loada(antStr)
#     200 #\return Returns a reference to the roadrunner model
#     201 def loada (antStr):
# --> 202     return loadAntimonyModel (antStr)
#     203
#     204 ##\brief Reads a CellML string into roadrunner
#
# /usr/local/lib/python2.7/dist-packages/tellurium/tellurium.pyc in loadAntimonyModel(antStr)
#     187     Id = antimony.getMainModuleName()
#     188     sbmlStr = antimony.getSBMLString(Id)
# --> 189     rr = roadrunner.RoadRunner(sbmlStr)
#     190
#     191     antimony.clearPreviousLoads()
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in _new_init(self, *args)
#    2632
#    2633     def _new_init(self, *args):
# -> 2634         RoadRunner._swig_init(self, *args)
#    2635         RoadRunner._makeProperties(self)
#    2636
#
# /usr/local/lib/python2.7/dist-packages/roadrunner/roadrunner.pyc in __init__(self, *args)
#    1898     __getattr__ = lambda self, name: _swig_getattr(self, RoadRunner, name)
#    1899     def __init__(self, *args):
# -> 1900         this = _roadrunner.new_RoadRunner(*args)
#    1901         try: self.this.append(this)
#    1902         except: self.this = this
#
# RuntimeError: Global parameter 'compartment_' missing value and missing init assignment and assignment rule!

# %%
import tellurium as te
import numpy
import matplotlib.pyplot as plt


# Using setHold to compare to simulaton runs. In tihs case one
# simulation is a determinsitic run and the second is a stochastic
# simulation.

r = te.loada ('''
     v1: $Xo -> S1;  k1*Xo;
     v2: S1 -> $w;   k2*S1;

     //initialize.  Deterministic process.
     k1 = 1; k2 = 1; S1 = 20; Xo = 1;
''')

m1 = r.simulate (0,20,100);

# Stochastic process
r.resetToOrigin()
m2 = r.gillespie (0, 20, 100, ['time', 'S1'])

# plot all the results together
te.setHold (True)
te.plotArray (m1)
te.plotArray (m2)

# %%
import tellurium as te
import numpy

# Example that show how to inject a sinusoidal into the model
# and use events to switch it off and on

r = te.loada ('''
    # Inject sin wave into model    
    Xo := sin (time*0.5)*switch + 2;    
    
    # Model Definition
    v1: $Xo -> S1;  k1*Xo;
    v2: S1 -> S2;   k2*S1;
    v3: S2 -> $X1;  k3*S2;

    at (time > 40): switch = 1;
    at (time > 80): switch = 0.5;
    
    # Initialize constants 
    k1 = 1; k2 = 1; k3 = 3; S1 = 3; 
    S2 = 0; 
    switch = 0;
''')

result = r.simulate (0, 100, 200, ['time', 'S1', 'S2'])
r.plot (result)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc'>

# %%
import tellurium as te
import numpy as np

# Simple protein phosphorylation cycle. Steady state concentation
# of the phosphorylated protein is plotted as a funtion of the cycle
# kinase. In addition, the plot is repeated for various values of Km.

r = te.loada ('''
   S1 -> S2; k1*S1/(Km1 + S1);
   S2 -> S1; k2*S2/(Km2 + S2);
   
   k1 = 0.1; k2 = 0.4; S1 = 10; S2 = 0;
   Km1 = 0.1; Km2 = 0.1;  
''')

r.conservedMoietyAnalysis = True

te.setHold (True)
for i in range (1,8):
  numbers = np.linspace (0.1, 1.2, 200)
  result = np.empty ([0,2])
  for value in numbers:
      r.k1 = value
      r.steadyState()
      row = np.array ([value, r.S2])
      result = np.vstack ((result, row))
  te.plotArray (result)
  r.model.k1 = 0.1
  r.model.Km1 = r.Km1 + 0.5;
  r.model.Km2 = r.Km2 + 0.5;

# %%
# %matplotlib inline
import roadrunner
from roadrunner import SelectionRecord
from roadrunner import Config, SelectionRecord, Logger

#Logger.setLevel(Logger.LOG_DEBUG)

import tellurium as te

m = te.loada('''
var species x in c, y in c, z in c
compartment c = 1.0

x -> y ; k*x
y -> z; 1

x = 10
y = 0
z = 0

k = 0.2


''')
#at time>5: c=2.0

r = m.simulate(0,10,100,['time','[x]','[y]','[z]'])
print(r)
m.plot()

print('[x] at final timepoint: {}'.format(m.model.getValue('[x]')))
m.model.setValue('c', 2.)
print('[x] after vol change: {}'.format(m.model.getValue('[x]')))
print('c after vol change: {}'.format(m.model.getValue('c')))
m.reset(SelectionRecord.INITIAL_FLOATING_CONCENTRATION)

print('[x] after floating conc reset: {}'.format(m.model.getValue('[x]')))
print('x after floating conc reset: {}'.format(m.model.getValue('x')))
# Out:
#         time,     [x],         [y],      [z]
#  [[        0,      10,           0,        0],
#   [  0.10101, 9.80001,   0.0989837,  0.10101],
#   [  0.20202, 9.60401,    0.193967,  0.20202],
#   [  0.30303, 9.41194,     0.28503,  0.30303],
#   [  0.40404, 9.22371,    0.372252,  0.40404],
#   [ 0.505051, 9.03924,    0.455705, 0.505051],
#   [ 0.606061, 8.85847,    0.535469, 0.606061],
#   [ 0.707071, 8.68131,    0.611618, 0.707071],
#   [ 0.808081,  8.5077,    0.684222, 0.808081],
#   [ 0.909091, 8.33755,    0.753356, 0.909091],
#   [   1.0101, 8.17081,    0.819088,   1.0101],
#   [  1.11111,  8.0074,    0.881487,  1.11111],
#   [  1.21212, 7.84726,    0.940619,  1.21212],
#   [  1.31313, 7.69032,    0.996548,  1.31313],
#   [  1.41414, 7.53652,     1.04934,  1.41414],
#   [  1.51515, 7.38579,     1.09906,  1.51515],
#   [  1.61616, 7.23808,     1.14576,  1.61616],
#   [  1.71717, 7.09332,      1.1895,  1.71717],
#   [  1.81818, 6.95146,     1.23036,  1.81818],
#   [  1.91919, 6.81244,     1.26837,  1.91919],
#   [   2.0202, 6.67619,     1.30361,   2.0202],
#   [  2.12121, 6.54267,     1.33611,  2.12121],
#   [  2.22222, 6.41182,     1.36595,  2.22222],
#   [  2.32323, 6.28359,     1.39318,  2.32323],
#   [  2.42424, 6.15792,     1.41783,  2.42424],
#   [  2.52525, 6.03477,     1.43998,  2.52525],
#   [  2.62626, 5.91407,     1.45966,  2.62626],
#   [  2.72727, 5.79579,     1.47693,  2.72727],
#   [  2.82828, 5.67988,     1.49184,  2.82828],
#   [  2.92929, 5.56628,     1.50443,  2.92929],
#   [   3.0303, 5.45495,     1.51475,   3.0303],
#   [  3.13131, 5.34585,     1.52283,  3.13131],
#   [  3.23232, 5.23894,     1.52874,  3.23232],
#   [  3.33333, 5.13416,     1.53251,  3.33333],
#   [  3.43434, 5.03147,     1.53419,  3.43434],
#   [  3.53535, 4.93084,     1.53381,  3.53535],
#   [  3.63636, 4.83222,     1.53141,  3.63636],
#   [  3.73737, 4.73558,     1.52704,  3.73737],
#   [  3.83838, 4.64087,     1.52075,  3.83838],
#   [  3.93939, 4.54805,     1.51255,  3.93939],
#   [   4.0404, 4.45709,      1.5025,   4.0404],
#   [  4.14141, 4.36795,     1.49064,  4.14141],
#   [  4.24242, 4.28059,     1.47698,  4.24242],
#   [  4.34343, 4.19498,     1.46158,  4.34343],
#   [  4.44444, 4.11108,     1.44447,  4.44444],
#   [  4.54545, 4.02886,     1.42568,  4.54545],
#   [  4.64646, 3.94829,     1.40525,  4.64646],
#   [  4.74747, 3.86932,      1.3832,  4.74747],
#   [  4.84848, 3.79194,     1.35958,  4.84848],
#   [  4.94949,  3.7161,     1.33441,  4.94949],
#   [  5.05051, 3.64178,     1.30772,  5.05051],
#   [  5.15152, 3.56894,     1.27954,  5.15152],
#   [  5.25253, 3.49756,     1.24991,  5.25253],
#   [  5.35354, 3.42761,     1.21885,  5.35354],
#   [  5.45455, 3.35906,     1.18639,  5.45455],
#   [  5.55556, 3.29188,     1.15256,  5.55556],
#   [  5.65657, 3.22604,     1.11739,  5.65657],
#   [  5.75758, 3.16152,      1.0809,  5.75758],
#   [  5.85859, 3.09829,     1.04312,  5.85859],
#   [   5.9596, 3.03633,     1.00408,   5.9596],
#   [  6.06061,  2.9756,    0.963797,  6.06061],
#   [  6.16162, 2.91608,    0.922301,  6.16162],
#   [  6.26263, 2.85776,    0.879615,  6.26263],
#   [  6.36364,  2.8006,    0.835761,  6.36364],
#   [  6.46465, 2.74459,    0.790764,  6.46465],
#   [  6.56566,  2.6897,    0.744645,  6.56566],
#   [  6.66667,  2.6359,     0.69743,  6.66667],
#   [  6.76768, 2.58318,    0.649139,  6.76768],
#   [  6.86869, 2.53152,    0.599792,  6.86869],
#   [   6.9697, 2.48089,    0.549412,   6.9697],
#   [  7.07071, 2.43127,    0.498019,  7.07071],
#   [  7.17172, 2.38265,    0.445632,  7.17172],
#   [  7.27273,   2.335,    0.392273,  7.27273],
#   [  7.37374,  2.2883,    0.337961,  7.37374],
#   [  7.47475, 2.24254,    0.282714,  7.47475],
#   [  7.57576, 2.19769,    0.226553,  7.57576],
#   [  7.67677, 2.15374,    0.169494,  7.67677],
#   [  7.77778, 2.11067,    0.111556,  7.77778],
#   [  7.87879, 2.06846,   0.0527567,  7.87879],
#   [   7.9798, 2.02709, -0.00688691,   7.9798],
#   [  8.08081, 1.98655,  -0.0673575,  8.08081],
#   [  8.18182, 1.94682,   -0.128638,  8.18182],
#   [  8.28283, 1.90789,   -0.190714,  8.28283],
#   [  8.38384, 1.86973,   -0.253568,  8.38384],
#   [  8.48485, 1.83234,   -0.317185,  8.48485],
#   [  8.58586, 1.79569,    -0.38155,  8.58586],
#   [  8.68687, 1.75978,   -0.446647,  8.68687],
#   [  8.78788, 1.72458,   -0.512463,  8.78788],
#   [  8.88889, 1.69009,   -0.578982,  8.88889],
#   [   8.9899, 1.65629,   -0.646191,   8.9899],
#   [  9.09091, 1.62317,   -0.714076,  9.09091],
#   [  9.19192,  1.5907,   -0.782624,  9.19192],
#   [  9.29293, 1.55889,   -0.851821,  9.29293],
#   [  9.39394, 1.52771,   -0.921654,  9.39394],
#   [  9.49495, 1.49716,    -0.99211,  9.49495],
#   [  9.59596, 1.46722,    -1.06318,  9.59596],
#   [  9.69697, 1.43787,    -1.13484,  9.69697],
#   [  9.79798, 1.40912,     -1.2071,  9.79798],
#   [  9.89899, 1.38094,    -1.27993,  9.89899],
#   [       10, 1.35332,    -1.35332,       10]]
# [x] at final timepoint: 1.35331946673
# [x] after vol change: 0.676659733363
# c after vol change: 2.0
# [x] after floating conc reset: 10.0
# x after floating conc reset: 20.0
